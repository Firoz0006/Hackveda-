# %% [markdown]
# ## Import **Library**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from collections import Counter

sns.set()
# %matplotlib inline

# %% [markdown]
# ## Preprocessing

# %%
df_raw= pd.read_csv('/content/creditcard.csv')

# %%
df_raw.describe(include='all')
df_raw.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df_raw.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
# 5  0.105915  0.253844  0.081080    3.67    0.0
# 6 -0.257237  0.034507  0.005168    4.99    0.0
# 7 -0.051634 -1.206921 -1.085339   40.80    0.0
# 8 -0.384157  0.011747  0.142404   93.20    0.0
# 9  0.094199  0.246219  0.083076    3.68    0.0
#
# [10 rows x 31 columns]

# %%
df_raw.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7973 entries, 0 to 7972
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    7973 non-null   int64
#  1   V1      7973 non-null   float64
#  2   V2      7973 non-null   float64
#  3   V3      7973 non-null   float64
#  4   V4      7973 non-null   float64
#  5   V5      7973 non-null   float64
#  6   V6      7973 non-null   float64
#  7   V7      7973 non-null   float64
#  8   V8      7973 non-null   float64
#  9   V9      7973 non-null   float64
#  10  V10     7973 non-null   float64
#  11  V11     7973 non-null   float64
#  12  V12     7973 non-null   float64
#  13  V13     7973 non-null   float64
#  14  V14     7973 non-null   float64
#  15  V15     7972 non-null   float64
#  16  V16     7972 non-null   float64
#  17  V17     7972 non-null   float64
#  18  V18     7972 non-null   float64
#  19  V19     7972 non-null   float64
#  20  V20     7972 non-null   float64
#  21  V21     7972 non-null   float64
#  22  V22     7972 non-null   float64
#  23  V23     7972 non-null   float64
#  24  V24     7972 non-null   float64
#  25  V25     7972 non-null   float64
#  26  V26     7972 non-null   float64
#  27  V27     7972 non-null   float64
#  28  V28     7972 non-null   float64
#  29  Amount  7972 non-null   float64
#  30  Class   7972 non-null   float64
# dtypes: float64(30), int64(1)
# memory usage: 1.9 MB

# %%
df=df_raw.drop(['Time'], axis=1)

# %%
len(df[df['Class'] == 1])
# Out:
# 25

# %%
len(df[df['Class'] == 0])
# Out:
# 7947

# %%
sns.countplot(x='Class', data=df, palette='CMRmap')
print('Non-fraud transactions: {}%'.format(round(df.Class.value_counts()[0]/len(df)*100.0,2)))
print('Fraud transactions: {}%'.format(round(df.Class.value_counts()[1]/len(df)*100.0,2)))
# Out:
# <ipython-input-23-58b3b3d1fc9f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=df, palette='CMRmap')
# Non-fraud transactions: 99.67%
# Fraud transactions: 0.31%

# %% [markdown]
# # Correlations and most important **features**

# %%
df.corr()['Class'].sort_values()
# Out:
# V14      -0.399364
# V3       -0.291009
# V12      -0.257452
# V10      -0.251419
# V17      -0.236978
# V16      -0.171556
# V7       -0.114739
# V9       -0.108488
# V6       -0.089314
# V1       -0.031975
# V5       -0.029357
# V18      -0.027836
# V24      -0.019518
# V13      -0.014304
# V15      -0.011483
# V23      -0.009342
# V22      -0.008558
# V19      -0.004862
# V25      -0.002810
# Amount    0.011769
# V20       0.020364
# V26       0.025664
# V21       0.026315
# V8        0.030239
# V28       0.048056
# V27       0.056351
# V2        0.115137
# V4        0.169556
# V11       0.225635
# Class     1.000000
# Name: Class, dtype: float64

# %%
plt.figure(figsize=(15,8))
d = df.corr()['Class'][:-1].abs().sort_values().plot(kind='bar', title='Most important features')

plt.show()

# %%
# Let's peak all features with correlation 0.15 and morec =

c = df.corr()['Class'][:-1].abs() > 0.15

print (c)
# Out:
# V1        False
# V2        False
# V3         True
# V4         True
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10        True
# V11        True
# V12        True
# V13       False
# V14        True
# V15       False
# V16        True
# V17        True
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Name: Class, dtype: bool

# %%
sns.jointplot(x='V17', y='V14',hue='Class', data=df, palette = 'dark')

# %%
sns.jointplot(x='V17', y='V12',hue='Class', data=df, palette = 'dark')

# %%
sns.jointplot(x='V17', y='V10',hue='Class', data=df, palette = 'dark')

# %%
sns.jointplot(x='V14', y='V12',hue='Class', data=df, palette = 'dark')

# %% [markdown]
# # outlier **Detection**

# %%
fig, axes = plt.subplots(nrows=3, ncols=3,figsize=(13,8))

axes[0,0].hist(df['V17'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,0].set_title("V17 distribution");

axes[0,1].hist(df['V10'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,1].set_title("V10 distribution");

axes[0,2].hist(df['V12'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,2].set_title("V12 distribution");

axes[1,0].hist(df['V16'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,0].set_title("V16 distribution");

axes[1,1].hist(df['V14'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,1].set_title("V14 distribution");

axes[1,2].hist(df['V3'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,2].set_title("V3 distribution");

axes[2,0].hist(df['V7'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,0].set_title("V7 distribution");

axes[2,1].hist(df['V11'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,1].set_title("V11 distribution");

axes[2,2].hist(df['V4'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,2].set_title("V4 distribution");

plt.tight_layout()

# %%
def detect_outliers(df,n,features):
    """
    Takes a dataframe df of features and returns an index list corresponding to the observations
    containing more than n outliers according to the Tukey IQR method.
    """
    outlier_indices = []

    # iterating over features(columns)
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1

        # outlier step
        outlier_step = 1.5 * IQR

        # Determining a list of indices of outliers for feature col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index

        # appending the found outlier indices for col to the list of outlier indices
        outlier_indices.extend(outlier_list_col)

    # selecting observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )

    return multiple_outliers

# detecting outliers
Outliers_IQR = detect_outliers(df,2,['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
       'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
       'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'])

# dropping outliers
df_out = df.drop(Outliers_IQR, axis = 0).reset_index(drop=True)

# %%
len(Outliers_IQR)
# Out:
# 391

# %%
df_out
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0    -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2    -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3    -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4    -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# ...        ...       ...       ...       ...       ...       ...       ...
# 7577  1.284388 -0.013181  0.646174  0.198985 -0.568675 -0.526121 -0.448235
# 7578  1.190428 -0.122329  0.954945  0.267101 -0.971026 -0.652279 -0.612992
# 7579 -0.725175  0.298202  1.824761 -2.587170  0.283605 -0.016617  0.153659
# 7580  1.226153 -0.129645  0.735197  0.142752 -0.703245 -0.349641 -0.612641
# 7581  1.145381 -0.059349  0.968088  0.267891 -0.822582 -0.597727 -0.450197
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 0     0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 1     0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
# 2     0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 3     0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 4    -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
# ...        ...       ...       ...  ...       ...       ...       ...
# 7577 -0.167709  1.773223 -0.519404  ... -0.101868 -0.030298 -0.081412
# 7578 -0.003909  1.633117 -0.318143  ... -0.015001  0.127027  0.012079
# 7579  0.045084 -0.197611 -0.674963  ... -0.017097 -0.070535 -0.442861
# 7580  0.020507  1.648986 -0.321755  ... -0.047936  0.040196 -0.057391
# 7581 -0.119747  1.338188 -0.386004  ...       NaN       NaN       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1    -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3    -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4     0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# ...        ...       ...       ...       ...       ...     ...    ...
# 7577 -0.123281  0.278808  1.064001 -0.090181  0.000481   15.95    0.0
# 7578  0.534409  0.112179  1.004483 -0.100188 -0.004774   14.95    0.0
# 7579 -0.895837  0.624743 -0.510601 -0.031142  0.025564   12.95    0.0
# 7580 -0.012386  0.187685  1.037786 -0.100081 -0.009869   15.95    0.0
# 7581       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [7582 rows x 30 columns]

# %%
# Checking distributions of most important features after dropping outliers

fig, axes = plt.subplots(nrows=3, ncols=3,figsize=(13,8))

axes[0,0].hist(df_out['V17'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,0].set_title("V17 distribution");

axes[0,1].hist(df_out['V10'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,1].set_title("V10 distribution");

axes[0,2].hist(df_out['V12'], bins=60, linewidth=0.5, edgecolor="white")
axes[0,2].set_title("V12 distribution");

axes[1,0].hist(df_out['V16'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,0].set_title("V16 distribution");

axes[1,1].hist(df_out['V14'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,1].set_title("V14 distribution");

axes[1,2].hist(df_out['V3'], bins=60, linewidth=0.5, edgecolor="white")
axes[1,2].set_title("V3 distribution");

axes[2,0].hist(df_out['V7'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,0].set_title("V7 distribution");

axes[2,1].hist(df_out['V11'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,1].set_title("V11 distribution");

axes[2,2].hist(df_out['V4'], bins=60, linewidth=0.5, edgecolor="white")
axes[2,2].set_title("V4 distribution");

plt.tight_layout()

# %%
print ('The amount of frauds in df before dropping outliers: ', len(df[df['Class'] == 1]))
# Out:
# The amount of frauds in df before dropping outliers:  25

# %%
print ('The amount of frauds in df afret dropping outliers: ', len(df_out[df_out['Class'] == 1]))
# Out:
# The amount of frauds in df afret dropping outliers:  2

# %%
Outliers_df2 = df.loc[df.index[Outliers_IQR]]

# %%
len(Outliers_df2)
# Out:
# 391

# %%
Outliers_df2
# Out:
#             V1         V2        V3        V4        V5        V6        V7  \
# 18   -5.401258  -5.450148  1.186305  1.736239  3.049106 -1.763406 -1.559738
# 85   -4.575093  -4.429184  3.402585  0.903915  3.002224 -0.491078 -2.705393
# 140  -5.101877   1.897022 -3.458034 -1.277543 -5.517758  2.098366  3.329603
# 146  -5.285971   4.847323 -1.290368 -1.427842 -0.621533 -0.604691  0.437866
# 164  -6.093248 -12.114213 -5.694973  3.294389 -1.413792  4.776000  4.808426
# ...        ...        ...       ...       ...       ...       ...       ...
# 7012 -3.235496   2.195631  1.694220 -0.492341  0.374107  0.000159 -0.646549
# 7066 -1.273936   1.197957  1.945026 -1.156206  1.642765  1.598267  1.476461
# 7145 -2.742515   2.064126  2.196278 -0.889241  0.440720 -0.288075  1.811172
# 7200 -3.298025   2.498591  1.732441 -0.906763  0.083443 -0.360252  1.438408
# 7639 -2.052886   1.311901  1.681978 -1.477561  0.244529 -0.001079  0.977432
#
#             V8        V9       V10  ...       V21       V22       V23  \
# 18    0.160842  1.233090  0.345173  ... -0.503600  0.984460  2.458589
# 85    0.666451  1.922216 -0.614312  ... -0.047365  0.853360 -0.971600
# 140   1.250966  0.271501 -0.305483  ... -0.871744 -0.678879 -0.555900
# 146   0.336384  3.558373  6.427802  ... -0.923604 -1.171187  0.150872
# 164  -0.228197 -0.525896 -1.724899  ...  2.228823 -2.264037 -3.553381
# ...        ...       ...       ...  ...       ...       ...       ...
# 7012 -2.786638  3.992945  2.234539  ...  1.662746 -0.856534 -0.720743
# 7066 -1.049945  3.785955  2.277951  ... -0.812183 -0.081551 -0.630404
# 7145 -1.630680  5.365180  4.255846  ... -1.088368 -0.068825 -0.295574
# 7200 -1.191249  5.387171  4.341106  ... -1.075328 -0.101223 -0.227438
# 7639 -1.011570  3.858381  1.720338  ... -0.431706  0.217772 -0.428978
#
#            V24       V25       V26       V27       V28   Amount  Class
# 18    0.042119 -0.481631 -0.621272  0.392053  0.949594    46.80    0.0
# 85   -0.114862  0.408300 -0.304576  0.547785 -0.456297   200.01    0.0
# 140  -0.761660  0.066611  0.767227  0.731634 -0.860310   919.60    0.0
# 146  -0.493322  1.050554  0.194865  2.490503  1.575380     8.95    0.0
# 164   1.215279 -0.406073 -0.653384 -0.711222  0.672900  3828.04    0.0
# ...        ...       ...       ...       ...       ...      ...    ...
# 7012  0.389101  0.141386  0.295104  0.792612  0.185663     0.01    0.0
# 7066 -1.727842  0.307020  0.280208 -0.204370 -1.066932     0.01    0.0
# 7145  0.323817  0.385197  0.103787 -0.363584 -1.519552     0.01    0.0
# 7200  0.318636  0.461080  0.110860 -0.384105 -1.521380     0.01    0.0
# 7639 -0.446526 -0.053860  0.778378 -1.285349 -0.874458    16.33    0.0
#
# [391 rows x 30 columns]

# %%
# Train/Test split

X = Outliers_df2.drop('Class',axis=1).values
y = Outliers_df2['Class'].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=42)

# %%
# Scaling data

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout

# %%
X_train.shape
# Out:
# (293, 29)

# %%
model = Sequential()

# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

model.add(Dense(units=29,activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=14,activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(units=7,activation='relu'))
#model.add(Dropout(0.1))

model.add(Dense(units=2,activation='relu'))

model.add(Dense(units=1,activation='sigmoid'))

# For a binary classification problem
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=2, patience=35)

# %%
model.fit(x=X_train,
          y=y_train,
          epochs=3000,
          validation_data=(X_test, y_test), verbose=2,
          callbacks=[early_stop]
          )
# Out:
# Streaming output truncated to the last 5000 lines.
# 10/10 - 0s - loss: 0.0036 - val_loss: 0.0016 - 63ms/epoch - 6ms/step
# Epoch 319/3000
# 10/10 - 0s - loss: 0.0036 - val_loss: 0.0016 - 53ms/epoch - 5ms/step
# Epoch 320/3000
# 10/10 - 0s - loss: 0.0036 - val_loss: 0.0016 - 51ms/epoch - 5ms/step
# Epoch 321/3000
# 10/10 - 0s - loss: 0.0049 - val_loss: 0.0016 - 56ms/epoch - 6ms/step
# Epoch 322/3000
# 10/10 - 0s - loss: 0.0036 - val_loss: 0.0016 - 68ms/epoch - 7ms/step
# Epoch 323/3000
# 10/10 - 0s - loss: 0.0146 - val_loss: 0.0016 - 70ms/epoch - 7ms/step
# Epoch 324/3000
# 10/10 - 0s - loss: 0.0035 - val_loss: 0.0016 - 48ms/epoch - 5ms/step
# Epoch 325/3000
# 10/10 - 0s - loss: 0.0036 - val_loss: 0.0016 - 64ms/epoch - 6ms/step
# Epoch 326/3000
# 10/10 - 0s - loss: 0.0038 - val_loss: 0.0016 - 67ms/epoch - 7ms/step
# Epoch 327/3000
# 10/10 - 0s - loss: 0.0035 - val_loss: 0.0016 - 49ms/epoch - 5ms/step
# Epoch 328/3000
# 10/10 - 0s - loss: 0.0035 - val_loss: 0.0015 - 65ms/epoch - 6ms/step
# Epoch 329/3000
# 10/10 - 0s - loss: 0.0037 - val_loss: 0.0015 - 63ms/epoch - 6ms/step
# Epoch 330/3000
# 10/10 - 0s - loss: 0.0036 - val_loss: 0.0015 - 50ms/epoch - 5ms/step
# Epoch 331/3000
# 10/10 - 0s - loss: 0.0035 - val_loss: 0.0015 - 65ms/epoch - 6ms/step
# Epoch 332/3000
# 10/10 - 0s - loss: 0.0035 - val_loss: 0.0015 - 52ms/epoch - 5ms/step
# Epoch 333/3000
# 10/10 - 0s - loss: 0.0047 - val_loss: 0.0015 - 64ms/epoch - 6ms/step
# Epoch 334/3000
# 10/10 - 0s - loss: 0.0035 - val_loss: 0.0015 - 51ms/epoch - 5ms/step
# Epoch 335/3000
# 10/10 - 0s - loss: 0.0034 - val_loss: 0.0015 - 67ms/epoch - 7ms/step
# Epoch 336/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 56ms/epoch - 6ms/step
# Epoch 337/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 65ms/epoch - 7ms/step
# Epoch 338/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 75ms/epoch - 8ms/step
# Epoch 339/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 76ms/epoch - 8ms/step
# Epoch 340/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 70ms/epoch - 7ms/step
# Epoch 341/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 70ms/epoch - 7ms/step
# Epoch 342/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 73ms/epoch - 7ms/step
# Epoch 343/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0015 - 76ms/epoch - 8ms/step
# Epoch 344/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0015 - 59ms/epoch - 6ms/step
# Epoch 345/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0014 - 59ms/epoch - 6ms/step
# Epoch 346/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0014 - 58ms/epoch - 6ms/step
# Epoch 347/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0014 - 70ms/epoch - 7ms/step
# Epoch 348/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0014 - 58ms/epoch - 6ms/step
# Epoch 349/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0014 - 64ms/epoch - 6ms/step
# Epoch 350/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0014 - 70ms/epoch - 7ms/step
# Epoch 351/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0014 - 71ms/epoch - 7ms/step
# Epoch 352/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0014 - 69ms/epoch - 7ms/step
# Epoch 353/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0014 - 65ms/epoch - 7ms/step
# Epoch 354/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0014 - 75ms/epoch - 7ms/step
# Epoch 355/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0014 - 65ms/epoch - 6ms/step
# Epoch 356/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0014 - 66ms/epoch - 7ms/step
# Epoch 357/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0014 - 65ms/epoch - 6ms/step
# Epoch 358/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0014 - 50ms/epoch - 5ms/step
# Epoch 359/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0014 - 49ms/epoch - 5ms/step
# Epoch 360/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0014 - 54ms/epoch - 5ms/step
# Epoch 361/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0014 - 51ms/epoch - 5ms/step
# Epoch 362/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 0.0014 - 50ms/epoch - 5ms/step
# Epoch 363/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 0.0013 - 66ms/epoch - 7ms/step
# Epoch 364/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 0.0013 - 66ms/epoch - 7ms/step
# Epoch 365/3000
# 10/10 - 0s - loss: 0.0034 - val_loss: 0.0013 - 50ms/epoch - 5ms/step
# Epoch 366/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 0.0013 - 50ms/epoch - 5ms/step
# Epoch 367/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 0.0013 - 48ms/epoch - 5ms/step
# Epoch 368/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 0.0013 - 58ms/epoch - 6ms/step
# Epoch 369/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 72ms/epoch - 7ms/step
# Epoch 370/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 82ms/epoch - 8ms/step
# Epoch 371/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 64ms/epoch - 6ms/step
# Epoch 372/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 60ms/epoch - 6ms/step
# Epoch 373/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 56ms/epoch - 6ms/step
# Epoch 374/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 59ms/epoch - 6ms/step
# Epoch 375/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 64ms/epoch - 6ms/step
# Epoch 376/3000
# 10/10 - 0s - loss: 0.0029 - val_loss: 0.0013 - 59ms/epoch - 6ms/step
# Epoch 377/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0013 - 62ms/epoch - 6ms/step
# Epoch 378/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0013 - 70ms/epoch - 7ms/step
# Epoch 379/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0013 - 60ms/epoch - 6ms/step
# Epoch 380/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0013 - 58ms/epoch - 6ms/step
# Epoch 381/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0013 - 80ms/epoch - 8ms/step
# Epoch 382/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0012 - 71ms/epoch - 7ms/step
# Epoch 383/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0012 - 56ms/epoch - 6ms/step
# Epoch 384/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0012 - 69ms/epoch - 7ms/step
# Epoch 385/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0012 - 82ms/epoch - 8ms/step
# Epoch 386/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0012 - 75ms/epoch - 8ms/step
# Epoch 387/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 65ms/epoch - 6ms/step
# Epoch 388/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 61ms/epoch - 6ms/step
# Epoch 389/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 59ms/epoch - 6ms/step
# Epoch 390/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 59ms/epoch - 6ms/step
# Epoch 391/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 64ms/epoch - 6ms/step
# Epoch 392/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 70ms/epoch - 7ms/step
# Epoch 393/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 70ms/epoch - 7ms/step
# Epoch 394/3000
# 10/10 - 0s - loss: 0.0139 - val_loss: 0.0012 - 72ms/epoch - 7ms/step
# Epoch 395/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 81ms/epoch - 8ms/step
# Epoch 396/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 0.0012 - 75ms/epoch - 7ms/step
# Epoch 397/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 68ms/epoch - 7ms/step
# Epoch 398/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 75ms/epoch - 8ms/step
# Epoch 399/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 84ms/epoch - 8ms/step
# Epoch 400/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 59ms/epoch - 6ms/step
# Epoch 401/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 58ms/epoch - 6ms/step
# Epoch 402/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 57ms/epoch - 6ms/step
# Epoch 403/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 75ms/epoch - 7ms/step
# Epoch 404/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0012 - 82ms/epoch - 8ms/step
# Epoch 405/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0011 - 61ms/epoch - 6ms/step
# Epoch 406/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0011 - 60ms/epoch - 6ms/step
# Epoch 407/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0011 - 64ms/epoch - 6ms/step
# Epoch 408/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0011 - 59ms/epoch - 6ms/step
# Epoch 409/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0011 - 64ms/epoch - 6ms/step
# Epoch 410/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0011 - 74ms/epoch - 7ms/step
# Epoch 411/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0011 - 72ms/epoch - 7ms/step
# Epoch 412/3000
# 10/10 - 0s - loss: 0.0042 - val_loss: 0.0011 - 50ms/epoch - 5ms/step
# Epoch 413/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 0.0011 - 54ms/epoch - 5ms/step
# Epoch 414/3000
# 10/10 - 0s - loss: 0.0034 - val_loss: 0.0011 - 64ms/epoch - 6ms/step
# Epoch 415/3000
# 10/10 - 0s - loss: 0.0032 - val_loss: 0.0011 - 65ms/epoch - 6ms/step
# Epoch 416/3000
# 10/10 - 0s - loss: 0.0065 - val_loss: 0.0011 - 52ms/epoch - 5ms/step
# Epoch 417/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0011 - 52ms/epoch - 5ms/step
# Epoch 418/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 0.0011 - 53ms/epoch - 5ms/step
# Epoch 419/3000
# 10/10 - 0s - loss: 0.0028 - val_loss: 0.0011 - 50ms/epoch - 5ms/step
# Epoch 420/3000
# 10/10 - 0s - loss: 0.0049 - val_loss: 0.0011 - 66ms/epoch - 7ms/step
# Epoch 421/3000
# 10/10 - 0s - loss: 0.0024 - val_loss: 0.0011 - 50ms/epoch - 5ms/step
# Epoch 422/3000
# 10/10 - 0s - loss: 0.0037 - val_loss: 0.0011 - 52ms/epoch - 5ms/step
# Epoch 423/3000
# 10/10 - 0s - loss: 0.0024 - val_loss: 0.0011 - 53ms/epoch - 5ms/step
# Epoch 424/3000
# 10/10 - 0s - loss: 0.0125 - val_loss: 0.0011 - 65ms/epoch - 6ms/step
# Epoch 425/3000
# 10/10 - 0s - loss: 0.0024 - val_loss: 0.0011 - 60ms/epoch - 6ms/step
# Epoch 426/3000
# 10/10 - 0s - loss: 0.0043 - val_loss: 0.0011 - 51ms/epoch - 5ms/step
# Epoch 427/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0011 - 50ms/epoch - 5ms/step
# Epoch 428/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 0.0011 - 68ms/epoch - 7ms/step
# Epoch 429/3000
# 10/10 - 0s - loss: 0.0025 - val_loss: 0.0010 - 99ms/epoch - 10ms/step
# Epoch 430/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 109ms/epoch - 11ms/step
# Epoch 431/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 103ms/epoch - 10ms/step
# Epoch 432/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 99ms/epoch - 10ms/step
# Epoch 433/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 89ms/epoch - 9ms/step
# Epoch 434/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 97ms/epoch - 10ms/step
# Epoch 435/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 90ms/epoch - 9ms/step
# Epoch 436/3000
# 10/10 - 0s - loss: 0.0034 - val_loss: 0.0010 - 88ms/epoch - 9ms/step
# Epoch 437/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 115ms/epoch - 12ms/step
# Epoch 438/3000
# 10/10 - 0s - loss: 0.0038 - val_loss: 0.0010 - 95ms/epoch - 10ms/step
# Epoch 439/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 0.0010 - 100ms/epoch - 10ms/step
# Epoch 440/3000
# 10/10 - 0s - loss: 0.0033 - val_loss: 0.0010 - 80ms/epoch - 8ms/step
# Epoch 441/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 1.0000e-03 - 109ms/epoch - 11ms/step
# Epoch 442/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.9649e-04 - 81ms/epoch - 8ms/step
# Epoch 443/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.9312e-04 - 86ms/epoch - 9ms/step
# Epoch 444/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.8956e-04 - 95ms/epoch - 10ms/step
# Epoch 445/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.8617e-04 - 92ms/epoch - 9ms/step
# Epoch 446/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 9.8298e-04 - 96ms/epoch - 10ms/step
# Epoch 447/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.7906e-04 - 94ms/epoch - 9ms/step
# Epoch 448/3000
# 10/10 - 0s - loss: 0.0036 - val_loss: 9.7439e-04 - 79ms/epoch - 8ms/step
# Epoch 449/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.7038e-04 - 92ms/epoch - 9ms/step
# Epoch 450/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.6672e-04 - 75ms/epoch - 7ms/step
# Epoch 451/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.6319e-04 - 88ms/epoch - 9ms/step
# Epoch 452/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.5975e-04 - 96ms/epoch - 10ms/step
# Epoch 453/3000
# 10/10 - 0s - loss: 0.0022 - val_loss: 9.5640e-04 - 97ms/epoch - 10ms/step
# Epoch 454/3000
# 10/10 - 0s - loss: 0.0024 - val_loss: 9.5316e-04 - 88ms/epoch - 9ms/step
# Epoch 455/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.5149e-04 - 86ms/epoch - 9ms/step
# Epoch 456/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.4803e-04 - 95ms/epoch - 9ms/step
# Epoch 457/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.4456e-04 - 87ms/epoch - 9ms/step
# Epoch 458/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.4131e-04 - 88ms/epoch - 9ms/step
# Epoch 459/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.3679e-04 - 101ms/epoch - 10ms/step
# Epoch 460/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.3341e-04 - 79ms/epoch - 8ms/step
# Epoch 461/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.2984e-04 - 84ms/epoch - 8ms/step
# Epoch 462/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.2634e-04 - 83ms/epoch - 8ms/step
# Epoch 463/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.2319e-04 - 92ms/epoch - 9ms/step
# Epoch 464/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 9.1980e-04 - 87ms/epoch - 9ms/step
# Epoch 465/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 9.1661e-04 - 89ms/epoch - 9ms/step
# Epoch 466/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 9.1296e-04 - 88ms/epoch - 9ms/step
# Epoch 467/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 9.0949e-04 - 72ms/epoch - 7ms/step
# Epoch 468/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 9.0609e-04 - 51ms/epoch - 5ms/step
# Epoch 469/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 9.0288e-04 - 67ms/epoch - 7ms/step
# Epoch 470/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.9912e-04 - 67ms/epoch - 7ms/step
# Epoch 471/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.9473e-04 - 50ms/epoch - 5ms/step
# Epoch 472/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.9090e-04 - 51ms/epoch - 5ms/step
# Epoch 473/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.8676e-04 - 53ms/epoch - 5ms/step
# Epoch 474/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.8333e-04 - 65ms/epoch - 7ms/step
# Epoch 475/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.7999e-04 - 66ms/epoch - 7ms/step
# Epoch 476/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.7582e-04 - 51ms/epoch - 5ms/step
# Epoch 477/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.7193e-04 - 51ms/epoch - 5ms/step
# Epoch 478/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.6862e-04 - 71ms/epoch - 7ms/step
# Epoch 479/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.6541e-04 - 64ms/epoch - 6ms/step
# Epoch 480/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.6248e-04 - 57ms/epoch - 6ms/step
# Epoch 481/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.5942e-04 - 75ms/epoch - 8ms/step
# Epoch 482/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.5646e-04 - 52ms/epoch - 5ms/step
# Epoch 483/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.5335e-04 - 51ms/epoch - 5ms/step
# Epoch 484/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.5048e-04 - 66ms/epoch - 7ms/step
# Epoch 485/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.4693e-04 - 54ms/epoch - 5ms/step
# Epoch 486/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.4384e-04 - 52ms/epoch - 5ms/step
# Epoch 487/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.4031e-04 - 67ms/epoch - 7ms/step
# Epoch 488/3000
# 10/10 - 0s - loss: 0.0045 - val_loss: 8.3897e-04 - 66ms/epoch - 7ms/step
# Epoch 489/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.3659e-04 - 65ms/epoch - 7ms/step
# Epoch 490/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.3403e-04 - 50ms/epoch - 5ms/step
# Epoch 491/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.3104e-04 - 53ms/epoch - 5ms/step
# Epoch 492/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 8.2812e-04 - 65ms/epoch - 7ms/step
# Epoch 493/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 8.2539e-04 - 56ms/epoch - 6ms/step
# Epoch 494/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 8.2255e-04 - 58ms/epoch - 6ms/step
# Epoch 495/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 8.1947e-04 - 55ms/epoch - 6ms/step
# Epoch 496/3000
# 10/10 - 0s - loss: 0.0107 - val_loss: 8.1375e-04 - 69ms/epoch - 7ms/step
# Epoch 497/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 8.0969e-04 - 57ms/epoch - 6ms/step
# Epoch 498/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 8.0657e-04 - 52ms/epoch - 5ms/step
# Epoch 499/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 8.0389e-04 - 57ms/epoch - 6ms/step
# Epoch 500/3000
# 10/10 - 0s - loss: 0.0024 - val_loss: 8.0114e-04 - 54ms/epoch - 5ms/step
# Epoch 501/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.9858e-04 - 64ms/epoch - 6ms/step
# Epoch 502/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.9593e-04 - 64ms/epoch - 6ms/step
# Epoch 503/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.9323e-04 - 65ms/epoch - 6ms/step
# Epoch 504/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.9056e-04 - 73ms/epoch - 7ms/step
# Epoch 505/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.8794e-04 - 66ms/epoch - 7ms/step
# Epoch 506/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.8512e-04 - 54ms/epoch - 5ms/step
# Epoch 507/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 7.8212e-04 - 51ms/epoch - 5ms/step
# Epoch 508/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.7894e-04 - 55ms/epoch - 6ms/step
# Epoch 509/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 7.7636e-04 - 54ms/epoch - 5ms/step
# Epoch 510/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.7308e-04 - 51ms/epoch - 5ms/step
# Epoch 511/3000
# 10/10 - 0s - loss: 0.0031 - val_loss: 7.7116e-04 - 62ms/epoch - 6ms/step
# Epoch 512/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.6912e-04 - 65ms/epoch - 6ms/step
# Epoch 513/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.6680e-04 - 66ms/epoch - 7ms/step
# Epoch 514/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.6415e-04 - 63ms/epoch - 6ms/step
# Epoch 515/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.6134e-04 - 51ms/epoch - 5ms/step
# Epoch 516/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.5831e-04 - 53ms/epoch - 5ms/step
# Epoch 517/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.5569e-04 - 54ms/epoch - 5ms/step
# Epoch 518/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.5296e-04 - 66ms/epoch - 7ms/step
# Epoch 519/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.5033e-04 - 56ms/epoch - 6ms/step
# Epoch 520/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.4769e-04 - 48ms/epoch - 5ms/step
# Epoch 521/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.4500e-04 - 69ms/epoch - 7ms/step
# Epoch 522/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.4191e-04 - 66ms/epoch - 7ms/step
# Epoch 523/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.3901e-04 - 73ms/epoch - 7ms/step
# Epoch 524/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.3646e-04 - 60ms/epoch - 6ms/step
# Epoch 525/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.3398e-04 - 64ms/epoch - 6ms/step
# Epoch 526/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.3136e-04 - 60ms/epoch - 6ms/step
# Epoch 527/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.2892e-04 - 88ms/epoch - 9ms/step
# Epoch 528/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.2657e-04 - 60ms/epoch - 6ms/step
# Epoch 529/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.2370e-04 - 62ms/epoch - 6ms/step
# Epoch 530/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.2114e-04 - 84ms/epoch - 8ms/step
# Epoch 531/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 7.1874e-04 - 75ms/epoch - 8ms/step
# Epoch 532/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 7.1620e-04 - 62ms/epoch - 6ms/step
# Epoch 533/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.1327e-04 - 72ms/epoch - 7ms/step
# Epoch 534/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.1064e-04 - 61ms/epoch - 6ms/step
# Epoch 535/3000
# 10/10 - 0s - loss: 0.0027 - val_loss: 7.0795e-04 - 59ms/epoch - 6ms/step
# Epoch 536/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.0434e-04 - 57ms/epoch - 6ms/step
# Epoch 537/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 7.0119e-04 - 59ms/epoch - 6ms/step
# Epoch 538/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 6.9851e-04 - 69ms/epoch - 7ms/step
# Epoch 539/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 6.9591e-04 - 65ms/epoch - 6ms/step
# Epoch 540/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 6.9340e-04 - 69ms/epoch - 7ms/step
# Epoch 541/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 6.9105e-04 - 51ms/epoch - 5ms/step
# Epoch 542/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.8860e-04 - 81ms/epoch - 8ms/step
# Epoch 543/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.8632e-04 - 54ms/epoch - 5ms/step
# Epoch 544/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.8394e-04 - 67ms/epoch - 7ms/step
# Epoch 545/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.8157e-04 - 68ms/epoch - 7ms/step
# Epoch 546/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.7885e-04 - 53ms/epoch - 5ms/step
# Epoch 547/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.7631e-04 - 74ms/epoch - 7ms/step
# Epoch 548/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 6.7425e-04 - 65ms/epoch - 6ms/step
# Epoch 549/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.7212e-04 - 66ms/epoch - 7ms/step
# Epoch 550/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 6.6952e-04 - 68ms/epoch - 7ms/step
# Epoch 551/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.6706e-04 - 73ms/epoch - 7ms/step
# Epoch 552/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.6434e-04 - 66ms/epoch - 7ms/step
# Epoch 553/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.6105e-04 - 53ms/epoch - 5ms/step
# Epoch 554/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.5854e-04 - 55ms/epoch - 6ms/step
# Epoch 555/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.5609e-04 - 66ms/epoch - 7ms/step
# Epoch 556/3000
# 10/10 - 0s - loss: 0.0105 - val_loss: 6.5700e-04 - 65ms/epoch - 7ms/step
# Epoch 557/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.5579e-04 - 59ms/epoch - 6ms/step
# Epoch 558/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.5390e-04 - 55ms/epoch - 5ms/step
# Epoch 559/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.5177e-04 - 67ms/epoch - 7ms/step
# Epoch 560/3000
# 10/10 - 0s - loss: 0.0016 - val_loss: 6.4913e-04 - 65ms/epoch - 6ms/step
# Epoch 561/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.4667e-04 - 64ms/epoch - 6ms/step
# Epoch 562/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.4407e-04 - 66ms/epoch - 7ms/step
# Epoch 563/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.4087e-04 - 64ms/epoch - 6ms/step
# Epoch 564/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.3811e-04 - 69ms/epoch - 7ms/step
# Epoch 565/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.3567e-04 - 51ms/epoch - 5ms/step
# Epoch 566/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 6.3337e-04 - 53ms/epoch - 5ms/step
# Epoch 567/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.3111e-04 - 54ms/epoch - 5ms/step
# Epoch 568/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.2897e-04 - 70ms/epoch - 7ms/step
# Epoch 569/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.2689e-04 - 72ms/epoch - 7ms/step
# Epoch 570/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.2475e-04 - 53ms/epoch - 5ms/step
# Epoch 571/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.2206e-04 - 65ms/epoch - 7ms/step
# Epoch 572/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.1976e-04 - 51ms/epoch - 5ms/step
# Epoch 573/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.1757e-04 - 61ms/epoch - 6ms/step
# Epoch 574/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.1550e-04 - 52ms/epoch - 5ms/step
# Epoch 575/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.1301e-04 - 67ms/epoch - 7ms/step
# Epoch 576/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.1101e-04 - 66ms/epoch - 7ms/step
# Epoch 577/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.0875e-04 - 57ms/epoch - 6ms/step
# Epoch 578/3000
# 10/10 - 0s - loss: 0.0148 - val_loss: 6.0978e-04 - 68ms/epoch - 7ms/step
# Epoch 579/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.0915e-04 - 57ms/epoch - 6ms/step
# Epoch 580/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.0738e-04 - 66ms/epoch - 7ms/step
# Epoch 581/3000
# 10/10 - 0s - loss: 0.0014 - val_loss: 6.0556e-04 - 70ms/epoch - 7ms/step
# Epoch 582/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 6.0358e-04 - 67ms/epoch - 7ms/step
# Epoch 583/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 6.0150e-04 - 67ms/epoch - 7ms/step
# Epoch 584/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.9878e-04 - 73ms/epoch - 7ms/step
# Epoch 585/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.9660e-04 - 58ms/epoch - 6ms/step
# Epoch 586/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.9448e-04 - 74ms/epoch - 7ms/step
# Epoch 587/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.9241e-04 - 74ms/epoch - 7ms/step
# Epoch 588/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.9043e-04 - 76ms/epoch - 8ms/step
# Epoch 589/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.8857e-04 - 74ms/epoch - 7ms/step
# Epoch 590/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.8650e-04 - 58ms/epoch - 6ms/step
# Epoch 591/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.8449e-04 - 65ms/epoch - 6ms/step
# Epoch 592/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.8244e-04 - 60ms/epoch - 6ms/step
# Epoch 593/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 5.7954e-04 - 71ms/epoch - 7ms/step
# Epoch 594/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.7698e-04 - 74ms/epoch - 7ms/step
# Epoch 595/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.7471e-04 - 72ms/epoch - 7ms/step
# Epoch 596/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.7236e-04 - 57ms/epoch - 6ms/step
# Epoch 597/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.7035e-04 - 76ms/epoch - 8ms/step
# Epoch 598/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.6835e-04 - 77ms/epoch - 8ms/step
# Epoch 599/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.6644e-04 - 69ms/epoch - 7ms/step
# Epoch 600/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.6439e-04 - 59ms/epoch - 6ms/step
# Epoch 601/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.6252e-04 - 58ms/epoch - 6ms/step
# Epoch 602/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 5.6038e-04 - 67ms/epoch - 7ms/step
# Epoch 603/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 5.5833e-04 - 63ms/epoch - 6ms/step
# Epoch 604/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.5662e-04 - 59ms/epoch - 6ms/step
# Epoch 605/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 5.5478e-04 - 60ms/epoch - 6ms/step
# Epoch 606/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.5249e-04 - 63ms/epoch - 6ms/step
# Epoch 607/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.5058e-04 - 60ms/epoch - 6ms/step
# Epoch 608/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.4870e-04 - 71ms/epoch - 7ms/step
# Epoch 609/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.4680e-04 - 72ms/epoch - 7ms/step
# Epoch 610/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.4474e-04 - 73ms/epoch - 7ms/step
# Epoch 611/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.4268e-04 - 58ms/epoch - 6ms/step
# Epoch 612/3000
# 10/10 - 0s - loss: 0.0015 - val_loss: 5.4103e-04 - 57ms/epoch - 6ms/step
# Epoch 613/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.3930e-04 - 58ms/epoch - 6ms/step
# Epoch 614/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.3765e-04 - 75ms/epoch - 8ms/step
# Epoch 615/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.3577e-04 - 62ms/epoch - 6ms/step
# Epoch 616/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.3388e-04 - 73ms/epoch - 7ms/step
# Epoch 617/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.3209e-04 - 77ms/epoch - 8ms/step
# Epoch 618/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.3023e-04 - 107ms/epoch - 11ms/step
# Epoch 619/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.2817e-04 - 98ms/epoch - 10ms/step
# Epoch 620/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.2617e-04 - 94ms/epoch - 9ms/step
# Epoch 621/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.2406e-04 - 91ms/epoch - 9ms/step
# Epoch 622/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.2231e-04 - 103ms/epoch - 10ms/step
# Epoch 623/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.2049e-04 - 90ms/epoch - 9ms/step
# Epoch 624/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.1860e-04 - 89ms/epoch - 9ms/step
# Epoch 625/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.1686e-04 - 110ms/epoch - 11ms/step
# Epoch 626/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 5.1506e-04 - 83ms/epoch - 8ms/step
# Epoch 627/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 5.1292e-04 - 101ms/epoch - 10ms/step
# Epoch 628/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 5.1105e-04 - 95ms/epoch - 10ms/step
# Epoch 629/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 5.0932e-04 - 95ms/epoch - 9ms/step
# Epoch 630/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 5.0757e-04 - 102ms/epoch - 10ms/step
# Epoch 631/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 5.0554e-04 - 108ms/epoch - 11ms/step
# Epoch 632/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 5.0358e-04 - 102ms/epoch - 10ms/step
# Epoch 633/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 5.0152e-04 - 92ms/epoch - 9ms/step
# Epoch 634/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.9971e-04 - 104ms/epoch - 10ms/step
# Epoch 635/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.9770e-04 - 83ms/epoch - 8ms/step
# Epoch 636/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.9562e-04 - 81ms/epoch - 8ms/step
# Epoch 637/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.9381e-04 - 77ms/epoch - 8ms/step
# Epoch 638/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.9172e-04 - 73ms/epoch - 7ms/step
# Epoch 639/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.8998e-04 - 93ms/epoch - 9ms/step
# Epoch 640/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.8829e-04 - 92ms/epoch - 9ms/step
# Epoch 641/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.8658e-04 - 81ms/epoch - 8ms/step
# Epoch 642/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.8496e-04 - 93ms/epoch - 9ms/step
# Epoch 643/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.8304e-04 - 84ms/epoch - 8ms/step
# Epoch 644/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.8125e-04 - 89ms/epoch - 9ms/step
# Epoch 645/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.7949e-04 - 83ms/epoch - 8ms/step
# Epoch 646/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.7787e-04 - 76ms/epoch - 8ms/step
# Epoch 647/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.7614e-04 - 80ms/epoch - 8ms/step
# Epoch 648/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.7429e-04 - 89ms/epoch - 9ms/step
# Epoch 649/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.7253e-04 - 102ms/epoch - 10ms/step
# Epoch 650/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.7081e-04 - 85ms/epoch - 8ms/step
# Epoch 651/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.6919e-04 - 87ms/epoch - 9ms/step
# Epoch 652/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.6764e-04 - 84ms/epoch - 8ms/step
# Epoch 653/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 4.6592e-04 - 85ms/epoch - 8ms/step
# Epoch 654/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.6432e-04 - 89ms/epoch - 9ms/step
# Epoch 655/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.6269e-04 - 79ms/epoch - 8ms/step
# Epoch 656/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.6088e-04 - 89ms/epoch - 9ms/step
# Epoch 657/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.5919e-04 - 86ms/epoch - 9ms/step
# Epoch 658/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.5757e-04 - 89ms/epoch - 9ms/step
# Epoch 659/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.5595e-04 - 53ms/epoch - 5ms/step
# Epoch 660/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.5433e-04 - 58ms/epoch - 6ms/step
# Epoch 661/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.5270e-04 - 67ms/epoch - 7ms/step
# Epoch 662/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.5115e-04 - 55ms/epoch - 6ms/step
# Epoch 663/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.4966e-04 - 80ms/epoch - 8ms/step
# Epoch 664/3000
# 10/10 - 0s - loss: 0.0010 - val_loss: 4.4811e-04 - 65ms/epoch - 7ms/step
# Epoch 665/3000
# 10/10 - 0s - loss: 9.9758e-04 - val_loss: 4.4631e-04 - 53ms/epoch - 5ms/step
# Epoch 666/3000
# 10/10 - 0s - loss: 9.9410e-04 - val_loss: 4.4464e-04 - 51ms/epoch - 5ms/step
# Epoch 667/3000
# 10/10 - 0s - loss: 9.9041e-04 - val_loss: 4.4315e-04 - 54ms/epoch - 5ms/step
# Epoch 668/3000
# 10/10 - 0s - loss: 9.8782e-04 - val_loss: 4.4149e-04 - 51ms/epoch - 5ms/step
# Epoch 669/3000
# 10/10 - 0s - loss: 9.8271e-04 - val_loss: 4.3977e-04 - 67ms/epoch - 7ms/step
# Epoch 670/3000
# 10/10 - 0s - loss: 9.8004e-04 - val_loss: 4.3806e-04 - 57ms/epoch - 6ms/step
# Epoch 671/3000
# 10/10 - 0s - loss: 9.7573e-04 - val_loss: 4.3648e-04 - 55ms/epoch - 5ms/step
# Epoch 672/3000
# 10/10 - 0s - loss: 9.7209e-04 - val_loss: 4.3505e-04 - 66ms/epoch - 7ms/step
# Epoch 673/3000
# 10/10 - 0s - loss: 9.7198e-04 - val_loss: 4.3353e-04 - 54ms/epoch - 5ms/step
# Epoch 674/3000
# 10/10 - 0s - loss: 9.6544e-04 - val_loss: 4.3205e-04 - 67ms/epoch - 7ms/step
# Epoch 675/3000
# 10/10 - 0s - loss: 9.6205e-04 - val_loss: 4.3060e-04 - 52ms/epoch - 5ms/step
# Epoch 676/3000
# 10/10 - 0s - loss: 9.6525e-04 - val_loss: 4.2909e-04 - 68ms/epoch - 7ms/step
# Epoch 677/3000
# 10/10 - 0s - loss: 9.5601e-04 - val_loss: 4.2758e-04 - 64ms/epoch - 6ms/step
# Epoch 678/3000
# 10/10 - 0s - loss: 9.5232e-04 - val_loss: 4.2597e-04 - 68ms/epoch - 7ms/step
# Epoch 679/3000
# 10/10 - 0s - loss: 9.4850e-04 - val_loss: 4.2457e-04 - 77ms/epoch - 8ms/step
# Epoch 680/3000
# 10/10 - 0s - loss: 9.5064e-04 - val_loss: 4.2304e-04 - 66ms/epoch - 7ms/step
# Epoch 681/3000
# 10/10 - 0s - loss: 9.4173e-04 - val_loss: 4.2134e-04 - 53ms/epoch - 5ms/step
# Epoch 682/3000
# 10/10 - 0s - loss: 9.3983e-04 - val_loss: 4.1975e-04 - 67ms/epoch - 7ms/step
# Epoch 683/3000
# 10/10 - 0s - loss: 9.3464e-04 - val_loss: 4.1830e-04 - 66ms/epoch - 7ms/step
# Epoch 684/3000
# 10/10 - 0s - loss: 9.3176e-04 - val_loss: 4.1689e-04 - 67ms/epoch - 7ms/step
# Epoch 685/3000
# 10/10 - 0s - loss: 9.2799e-04 - val_loss: 4.1512e-04 - 66ms/epoch - 7ms/step
# Epoch 686/3000
# 10/10 - 0s - loss: 9.2419e-04 - val_loss: 4.1356e-04 - 67ms/epoch - 7ms/step
# Epoch 687/3000
# 10/10 - 0s - loss: 9.2039e-04 - val_loss: 4.1190e-04 - 53ms/epoch - 5ms/step
# Epoch 688/3000
# 10/10 - 0s - loss: 9.4401e-04 - val_loss: 4.1041e-04 - 66ms/epoch - 7ms/step
# Epoch 689/3000
# 10/10 - 0s - loss: 9.1370e-04 - val_loss: 4.0893e-04 - 52ms/epoch - 5ms/step
# Epoch 690/3000
# 10/10 - 0s - loss: 9.1120e-04 - val_loss: 4.0746e-04 - 67ms/epoch - 7ms/step
# Epoch 691/3000
# 10/10 - 0s - loss: 9.0735e-04 - val_loss: 4.0600e-04 - 70ms/epoch - 7ms/step
# Epoch 692/3000
# 10/10 - 0s - loss: 9.0399e-04 - val_loss: 4.0456e-04 - 51ms/epoch - 5ms/step
# Epoch 693/3000
# 10/10 - 0s - loss: 9.0360e-04 - val_loss: 4.0282e-04 - 52ms/epoch - 5ms/step
# Epoch 694/3000
# 10/10 - 0s - loss: 8.9821e-04 - val_loss: 4.0138e-04 - 68ms/epoch - 7ms/step
# Epoch 695/3000
# 10/10 - 0s - loss: 8.9337e-04 - val_loss: 3.9977e-04 - 72ms/epoch - 7ms/step
# Epoch 696/3000
# 10/10 - 0s - loss: 8.9335e-04 - val_loss: 3.9826e-04 - 51ms/epoch - 5ms/step
# Epoch 697/3000
# 10/10 - 0s - loss: 8.8656e-04 - val_loss: 3.9693e-04 - 68ms/epoch - 7ms/step
# Epoch 698/3000
# 10/10 - 0s - loss: 8.8445e-04 - val_loss: 3.9551e-04 - 69ms/epoch - 7ms/step
# Epoch 699/3000
# 10/10 - 0s - loss: 8.8083e-04 - val_loss: 3.9374e-04 - 56ms/epoch - 6ms/step
# Epoch 700/3000
# 10/10 - 0s - loss: 8.7671e-04 - val_loss: 3.9225e-04 - 52ms/epoch - 5ms/step
# Epoch 701/3000
# 10/10 - 0s - loss: 8.7322e-04 - val_loss: 3.9065e-04 - 56ms/epoch - 6ms/step
# Epoch 702/3000
# 10/10 - 0s - loss: 8.6952e-04 - val_loss: 3.8929e-04 - 56ms/epoch - 6ms/step
# Epoch 703/3000
# 10/10 - 0s - loss: 8.6692e-04 - val_loss: 3.8768e-04 - 76ms/epoch - 8ms/step
# Epoch 704/3000
# 10/10 - 0s - loss: 8.6329e-04 - val_loss: 3.8609e-04 - 56ms/epoch - 6ms/step
# Epoch 705/3000
# 10/10 - 0s - loss: 8.6478e-04 - val_loss: 3.8478e-04 - 70ms/epoch - 7ms/step
# Epoch 706/3000
# 10/10 - 0s - loss: 8.5692e-04 - val_loss: 3.8342e-04 - 79ms/epoch - 8ms/step
# Epoch 707/3000
# 10/10 - 0s - loss: 8.5457e-04 - val_loss: 3.8205e-04 - 72ms/epoch - 7ms/step
# Epoch 708/3000
# 10/10 - 0s - loss: 8.5076e-04 - val_loss: 3.8077e-04 - 63ms/epoch - 6ms/step
# Epoch 709/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 3.7970e-04 - 75ms/epoch - 7ms/step
# Epoch 710/3000
# 10/10 - 0s - loss: 8.8193e-04 - val_loss: 3.7867e-04 - 72ms/epoch - 7ms/step
# Epoch 711/3000
# 10/10 - 0s - loss: 8.4317e-04 - val_loss: 3.7756e-04 - 76ms/epoch - 8ms/step
# Epoch 712/3000
# 10/10 - 0s - loss: 8.4150e-04 - val_loss: 3.7616e-04 - 61ms/epoch - 6ms/step
# Epoch 713/3000
# 10/10 - 0s - loss: 8.3768e-04 - val_loss: 3.7481e-04 - 77ms/epoch - 8ms/step
# Epoch 714/3000
# 10/10 - 0s - loss: 8.3466e-04 - val_loss: 3.7346e-04 - 56ms/epoch - 6ms/step
# Epoch 715/3000
# 10/10 - 0s - loss: 8.4042e-04 - val_loss: 3.7191e-04 - 74ms/epoch - 7ms/step
# Epoch 716/3000
# 10/10 - 0s - loss: 8.2827e-04 - val_loss: 3.7050e-04 - 60ms/epoch - 6ms/step
# Epoch 717/3000
# 10/10 - 0s - loss: 8.2500e-04 - val_loss: 3.6922e-04 - 58ms/epoch - 6ms/step
# Epoch 718/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 3.6753e-04 - 55ms/epoch - 5ms/step
# Epoch 719/3000
# 10/10 - 0s - loss: 8.3587e-04 - val_loss: 3.6548e-04 - 51ms/epoch - 5ms/step
# Epoch 720/3000
# 10/10 - 0s - loss: 9.6032e-04 - val_loss: 3.6373e-04 - 69ms/epoch - 7ms/step
# Epoch 721/3000
# 10/10 - 0s - loss: 8.1685e-04 - val_loss: 3.6237e-04 - 52ms/epoch - 5ms/step
# Epoch 722/3000
# 10/10 - 0s - loss: 9.0125e-04 - val_loss: 3.6114e-04 - 64ms/epoch - 6ms/step
# Epoch 723/3000
# 10/10 - 0s - loss: 8.0483e-04 - val_loss: 3.5991e-04 - 57ms/epoch - 6ms/step
# Epoch 724/3000
# 10/10 - 0s - loss: 8.0162e-04 - val_loss: 3.5837e-04 - 58ms/epoch - 6ms/step
# Epoch 725/3000
# 10/10 - 0s - loss: 8.0733e-04 - val_loss: 3.5709e-04 - 89ms/epoch - 9ms/step
# Epoch 726/3000
# 10/10 - 0s - loss: 7.9636e-04 - val_loss: 3.5584e-04 - 66ms/epoch - 7ms/step
# Epoch 727/3000
# 10/10 - 0s - loss: 7.9355e-04 - val_loss: 3.5436e-04 - 65ms/epoch - 7ms/step
# Epoch 728/3000
# 10/10 - 0s - loss: 8.1104e-04 - val_loss: 3.5297e-04 - 70ms/epoch - 7ms/step
# Epoch 729/3000
# 10/10 - 0s - loss: 8.2205e-04 - val_loss: 3.5159e-04 - 69ms/epoch - 7ms/step
# Epoch 730/3000
# 10/10 - 0s - loss: 7.8298e-04 - val_loss: 3.5023e-04 - 51ms/epoch - 5ms/step
# Epoch 731/3000
# 10/10 - 0s - loss: 8.8954e-04 - val_loss: 3.4895e-04 - 54ms/epoch - 5ms/step
# Epoch 732/3000
# 10/10 - 0s - loss: 8.6038e-04 - val_loss: 3.4767e-04 - 67ms/epoch - 7ms/step
# Epoch 733/3000
# 10/10 - 0s - loss: 7.7455e-04 - val_loss: 3.4649e-04 - 51ms/epoch - 5ms/step
# Epoch 734/3000
# 10/10 - 0s - loss: 7.7468e-04 - val_loss: 3.4530e-04 - 67ms/epoch - 7ms/step
# Epoch 735/3000
# 10/10 - 0s - loss: 7.7510e-04 - val_loss: 3.4393e-04 - 68ms/epoch - 7ms/step
# Epoch 736/3000
# 10/10 - 0s - loss: 7.6602e-04 - val_loss: 3.4267e-04 - 51ms/epoch - 5ms/step
# Epoch 737/3000
# 10/10 - 0s - loss: 7.6508e-04 - val_loss: 3.4142e-04 - 66ms/epoch - 7ms/step
# Epoch 738/3000
# 10/10 - 0s - loss: 7.6041e-04 - val_loss: 3.4023e-04 - 68ms/epoch - 7ms/step
# Epoch 739/3000
# 10/10 - 0s - loss: 7.5757e-04 - val_loss: 3.3913e-04 - 55ms/epoch - 6ms/step
# Epoch 740/3000
# 10/10 - 0s - loss: 7.5487e-04 - val_loss: 3.3769e-04 - 67ms/epoch - 7ms/step
# Epoch 741/3000
# 10/10 - 0s - loss: 7.5169e-04 - val_loss: 3.3623e-04 - 65ms/epoch - 6ms/step
# Epoch 742/3000
# 10/10 - 0s - loss: 7.4873e-04 - val_loss: 3.3494e-04 - 72ms/epoch - 7ms/step
# Epoch 743/3000
# 10/10 - 0s - loss: 7.4609e-04 - val_loss: 3.3367e-04 - 58ms/epoch - 6ms/step
# Epoch 744/3000
# 10/10 - 0s - loss: 7.4411e-04 - val_loss: 3.3258e-04 - 55ms/epoch - 6ms/step
# Epoch 745/3000
# 10/10 - 0s - loss: 7.4127e-04 - val_loss: 3.3136e-04 - 55ms/epoch - 5ms/step
# Epoch 746/3000
# 10/10 - 0s - loss: 7.3780e-04 - val_loss: 3.3008e-04 - 55ms/epoch - 5ms/step
# Epoch 747/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 3.2855e-04 - 57ms/epoch - 6ms/step
# Epoch 748/3000
# 10/10 - 0s - loss: 7.3331e-04 - val_loss: 3.2717e-04 - 53ms/epoch - 5ms/step
# Epoch 749/3000
# 10/10 - 0s - loss: 7.2906e-04 - val_loss: 3.2602e-04 - 66ms/epoch - 7ms/step
# Epoch 750/3000
# 10/10 - 0s - loss: 7.5080e-04 - val_loss: 3.2484e-04 - 65ms/epoch - 7ms/step
# Epoch 751/3000
# 10/10 - 0s - loss: 7.8069e-04 - val_loss: 3.2358e-04 - 71ms/epoch - 7ms/step
# Epoch 752/3000
# 10/10 - 0s - loss: 8.5082e-04 - val_loss: 3.2259e-04 - 66ms/epoch - 7ms/step
# Epoch 753/3000
# 10/10 - 0s - loss: 7.1837e-04 - val_loss: 3.2147e-04 - 50ms/epoch - 5ms/step
# Epoch 754/3000
# 10/10 - 0s - loss: 7.2997e-04 - val_loss: 3.2032e-04 - 67ms/epoch - 7ms/step
# Epoch 755/3000
# 10/10 - 0s - loss: 7.1333e-04 - val_loss: 3.1924e-04 - 50ms/epoch - 5ms/step
# Epoch 756/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 3.1872e-04 - 50ms/epoch - 5ms/step
# Epoch 757/3000
# 10/10 - 0s - loss: 7.1005e-04 - val_loss: 3.1775e-04 - 63ms/epoch - 6ms/step
# Epoch 758/3000
# 10/10 - 0s - loss: 7.6250e-04 - val_loss: 3.1666e-04 - 66ms/epoch - 7ms/step
# Epoch 759/3000
# 10/10 - 0s - loss: 0.0023 - val_loss: 3.1443e-04 - 67ms/epoch - 7ms/step
# Epoch 760/3000
# 10/10 - 0s - loss: 7.0717e-04 - val_loss: 3.1298e-04 - 61ms/epoch - 6ms/step
# Epoch 761/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 3.1182e-04 - 50ms/epoch - 5ms/step
# Epoch 762/3000
# 10/10 - 0s - loss: 6.9550e-04 - val_loss: 3.1088e-04 - 55ms/epoch - 6ms/step
# Epoch 763/3000
# 10/10 - 0s - loss: 6.9286e-04 - val_loss: 3.0999e-04 - 66ms/epoch - 7ms/step
# Epoch 764/3000
# 10/10 - 0s - loss: 0.0021 - val_loss: 3.0983e-04 - 51ms/epoch - 5ms/step
# Epoch 765/3000
# 10/10 - 0s - loss: 7.2098e-04 - val_loss: 3.0930e-04 - 51ms/epoch - 5ms/step
# Epoch 766/3000
# 10/10 - 0s - loss: 6.8877e-04 - val_loss: 3.0824e-04 - 65ms/epoch - 7ms/step
# Epoch 767/3000
# 10/10 - 0s - loss: 6.8720e-04 - val_loss: 3.0724e-04 - 69ms/epoch - 7ms/step
# Epoch 768/3000
# 10/10 - 0s - loss: 7.2525e-04 - val_loss: 3.0620e-04 - 65ms/epoch - 6ms/step
# Epoch 769/3000
# 10/10 - 0s - loss: 7.5831e-04 - val_loss: 3.0506e-04 - 68ms/epoch - 7ms/step
# Epoch 770/3000
# 10/10 - 0s - loss: 0.0094 - val_loss: 3.0224e-04 - 67ms/epoch - 7ms/step
# Epoch 771/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 3.0040e-04 - 53ms/epoch - 5ms/step
# Epoch 772/3000
# 10/10 - 0s - loss: 7.8733e-04 - val_loss: 2.9927e-04 - 66ms/epoch - 7ms/step
# Epoch 773/3000
# 10/10 - 0s - loss: 6.8962e-04 - val_loss: 2.9838e-04 - 76ms/epoch - 8ms/step
# Epoch 774/3000
# 10/10 - 0s - loss: 6.6960e-04 - val_loss: 2.9744e-04 - 68ms/epoch - 7ms/step
# Epoch 775/3000
# 10/10 - 0s - loss: 9.4496e-04 - val_loss: 2.9635e-04 - 51ms/epoch - 5ms/step
# Epoch 776/3000
# 10/10 - 0s - loss: 0.0068 - val_loss: 2.9633e-04 - 57ms/epoch - 6ms/step
# Epoch 777/3000
# 10/10 - 0s - loss: 0.0121 - val_loss: 2.9908e-04 - 65ms/epoch - 7ms/step
# Epoch 778/3000
# 10/10 - 0s - loss: 0.0220 - val_loss: 2.9798e-04 - 53ms/epoch - 5ms/step
# Epoch 779/3000
# 10/10 - 0s - loss: 0.0038 - val_loss: 2.9549e-04 - 69ms/epoch - 7ms/step
# Epoch 780/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 2.9439e-04 - 55ms/epoch - 6ms/step
# Epoch 781/3000
# 10/10 - 0s - loss: 6.8752e-04 - val_loss: 2.9390e-04 - 57ms/epoch - 6ms/step
# Epoch 782/3000
# 10/10 - 0s - loss: 6.5542e-04 - val_loss: 2.9321e-04 - 60ms/epoch - 6ms/step
# Epoch 783/3000
# 10/10 - 0s - loss: 6.8822e-04 - val_loss: 2.9261e-04 - 62ms/epoch - 6ms/step
# Epoch 784/3000
# 10/10 - 0s - loss: 6.5225e-04 - val_loss: 2.9194e-04 - 73ms/epoch - 7ms/step
# Epoch 785/3000
# 10/10 - 0s - loss: 7.7830e-04 - val_loss: 2.9119e-04 - 62ms/epoch - 6ms/step
# Epoch 786/3000
# 10/10 - 0s - loss: 0.0013 - val_loss: 2.9063e-04 - 60ms/epoch - 6ms/step
# Epoch 787/3000
# 10/10 - 0s - loss: 6.7090e-04 - val_loss: 2.9031e-04 - 66ms/epoch - 7ms/step
# Epoch 788/3000
# 10/10 - 0s - loss: 7.8500e-04 - val_loss: 2.8976e-04 - 66ms/epoch - 7ms/step
# Epoch 789/3000
# 10/10 - 0s - loss: 0.0135 - val_loss: 2.8975e-04 - 87ms/epoch - 9ms/step
# Epoch 790/3000
# 10/10 - 0s - loss: 6.7467e-04 - val_loss: 2.9447e-04 - 59ms/epoch - 6ms/step
# Epoch 791/3000
# 10/10 - 0s - loss: 7.1848e-04 - val_loss: 2.9589e-04 - 56ms/epoch - 6ms/step
# Epoch 792/3000
# 10/10 - 0s - loss: 0.0059 - val_loss: 2.9557e-04 - 71ms/epoch - 7ms/step
# Epoch 793/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 2.9546e-04 - 73ms/epoch - 7ms/step
# Epoch 794/3000
# 10/10 - 0s - loss: 6.5879e-04 - val_loss: 2.9521e-04 - 75ms/epoch - 7ms/step
# Epoch 795/3000
# 10/10 - 0s - loss: 6.6403e-04 - val_loss: 2.9496e-04 - 59ms/epoch - 6ms/step
# Epoch 796/3000
# 10/10 - 0s - loss: 9.5212e-04 - val_loss: 2.9456e-04 - 69ms/epoch - 7ms/step
# Epoch 797/3000
# 10/10 - 0s - loss: 7.2063e-04 - val_loss: 2.9419e-04 - 67ms/epoch - 7ms/step
# Epoch 798/3000
# 10/10 - 0s - loss: 7.1972e-04 - val_loss: 2.9386e-04 - 66ms/epoch - 7ms/step
# Epoch 799/3000
# 10/10 - 0s - loss: 6.5496e-04 - val_loss: 2.9358e-04 - 59ms/epoch - 6ms/step
# Epoch 800/3000
# 10/10 - 0s - loss: 6.7642e-04 - val_loss: 2.9328e-04 - 66ms/epoch - 7ms/step
# Epoch 801/3000
# 10/10 - 0s - loss: 6.6141e-04 - val_loss: 2.9299e-04 - 54ms/epoch - 5ms/step
# Epoch 802/3000
# 10/10 - 0s - loss: 6.5295e-04 - val_loss: 2.9262e-04 - 52ms/epoch - 5ms/step
# Epoch 803/3000
# 10/10 - 0s - loss: 6.5349e-04 - val_loss: 2.9227e-04 - 68ms/epoch - 7ms/step
# Epoch 804/3000
# 10/10 - 0s - loss: 6.5154e-04 - val_loss: 2.9196e-04 - 76ms/epoch - 8ms/step
# Epoch 805/3000
# 10/10 - 0s - loss: 6.5155e-04 - val_loss: 2.9168e-04 - 52ms/epoch - 5ms/step
# Epoch 806/3000
# 10/10 - 0s - loss: 6.5769e-04 - val_loss: 2.9141e-04 - 52ms/epoch - 5ms/step
# Epoch 807/3000
# 10/10 - 0s - loss: 0.0059 - val_loss: 2.9158e-04 - 56ms/epoch - 6ms/step
# Epoch 808/3000
# 10/10 - 0s - loss: 7.6112e-04 - val_loss: 2.9167e-04 - 52ms/epoch - 5ms/step
# Epoch 809/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 2.9119e-04 - 70ms/epoch - 7ms/step
# Epoch 810/3000
# 10/10 - 0s - loss: 8.3059e-04 - val_loss: 2.9075e-04 - 63ms/epoch - 6ms/step
# Epoch 811/3000
# 10/10 - 0s - loss: 0.0079 - val_loss: 2.8957e-04 - 77ms/epoch - 8ms/step
# Epoch 812/3000
# 10/10 - 0s - loss: 6.4524e-04 - val_loss: 2.8896e-04 - 84ms/epoch - 8ms/step
# Epoch 813/3000
# 10/10 - 0s - loss: 0.0012 - val_loss: 2.8867e-04 - 85ms/epoch - 8ms/step
# Epoch 814/3000
# 10/10 - 0s - loss: 6.4345e-04 - val_loss: 2.8840e-04 - 86ms/epoch - 9ms/step
# Epoch 815/3000
# 10/10 - 0s - loss: 6.4289e-04 - val_loss: 2.8813e-04 - 74ms/epoch - 7ms/step
# Epoch 816/3000
# 10/10 - 0s - loss: 6.4264e-04 - val_loss: 2.8781e-04 - 81ms/epoch - 8ms/step
# Epoch 817/3000
# 10/10 - 0s - loss: 6.4237e-04 - val_loss: 2.8750e-04 - 73ms/epoch - 7ms/step
# Epoch 818/3000
# 10/10 - 0s - loss: 6.4084e-04 - val_loss: 2.8720e-04 - 79ms/epoch - 8ms/step
# Epoch 819/3000
# 10/10 - 0s - loss: 7.7402e-04 - val_loss: 2.8688e-04 - 75ms/epoch - 8ms/step
# Epoch 820/3000
# 10/10 - 0s - loss: 8.8042e-04 - val_loss: 2.8664e-04 - 85ms/epoch - 9ms/step
# Epoch 821/3000
# 10/10 - 0s - loss: 6.3910e-04 - val_loss: 2.8638e-04 - 69ms/epoch - 7ms/step
# Epoch 822/3000
# 10/10 - 0s - loss: 0.0089 - val_loss: 2.8695e-04 - 68ms/epoch - 7ms/step
# Epoch 823/3000
# 10/10 - 0s - loss: 6.6610e-04 - val_loss: 2.8695e-04 - 89ms/epoch - 9ms/step
# Epoch 824/3000
# 10/10 - 0s - loss: 6.3972e-04 - val_loss: 2.8676e-04 - 72ms/epoch - 7ms/step
# Epoch 825/3000
# 10/10 - 0s - loss: 0.0088 - val_loss: 2.8563e-04 - 66ms/epoch - 7ms/step
# Epoch 826/3000
# 10/10 - 0s - loss: 6.5124e-04 - val_loss: 2.8506e-04 - 83ms/epoch - 8ms/step
# Epoch 827/3000
# 10/10 - 0s - loss: 9.8542e-04 - val_loss: 2.8467e-04 - 78ms/epoch - 8ms/step
# Epoch 828/3000
# 10/10 - 0s - loss: 0.0166 - val_loss: 2.8492e-04 - 67ms/epoch - 7ms/step
# Epoch 829/3000
# 10/10 - 0s - loss: 6.3591e-04 - val_loss: 2.8523e-04 - 79ms/epoch - 8ms/step
# Epoch 830/3000
# 10/10 - 0s - loss: 6.5113e-04 - val_loss: 2.8509e-04 - 67ms/epoch - 7ms/step
# Epoch 831/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 2.8518e-04 - 88ms/epoch - 9ms/step
# Epoch 832/3000
# 10/10 - 0s - loss: 6.3591e-04 - val_loss: 2.8515e-04 - 65ms/epoch - 7ms/step
# Epoch 833/3000
# 10/10 - 0s - loss: 6.4099e-04 - val_loss: 2.8495e-04 - 82ms/epoch - 8ms/step
# Epoch 834/3000
# 10/10 - 0s - loss: 6.5031e-04 - val_loss: 2.8470e-04 - 83ms/epoch - 8ms/step
# Epoch 835/3000
# 10/10 - 0s - loss: 6.3457e-04 - val_loss: 2.8436e-04 - 82ms/epoch - 8ms/step
# Epoch 836/3000
# 10/10 - 0s - loss: 6.4239e-04 - val_loss: 2.8404e-04 - 76ms/epoch - 8ms/step
# Epoch 837/3000
# 10/10 - 0s - loss: 6.3566e-04 - val_loss: 2.8371e-04 - 93ms/epoch - 9ms/step
# Epoch 838/3000
# 10/10 - 0s - loss: 6.5767e-04 - val_loss: 2.8333e-04 - 102ms/epoch - 10ms/step
# Epoch 839/3000
# 10/10 - 0s - loss: 6.3896e-04 - val_loss: 2.8303e-04 - 107ms/epoch - 11ms/step
# Epoch 840/3000
# 10/10 - 0s - loss: 6.3114e-04 - val_loss: 2.8271e-04 - 89ms/epoch - 9ms/step
# Epoch 841/3000
# 10/10 - 0s - loss: 6.3013e-04 - val_loss: 2.8243e-04 - 99ms/epoch - 10ms/step
# Epoch 842/3000
# 10/10 - 0s - loss: 6.2951e-04 - val_loss: 2.8214e-04 - 97ms/epoch - 10ms/step
# Epoch 843/3000
# 10/10 - 0s - loss: 6.2890e-04 - val_loss: 2.8184e-04 - 107ms/epoch - 11ms/step
# Epoch 844/3000
# 10/10 - 0s - loss: 6.2817e-04 - val_loss: 2.8154e-04 - 78ms/epoch - 8ms/step
# Epoch 845/3000
# 10/10 - 0s - loss: 6.8282e-04 - val_loss: 2.8111e-04 - 88ms/epoch - 9ms/step
# Epoch 846/3000
# 10/10 - 0s - loss: 6.2649e-04 - val_loss: 2.8073e-04 - 93ms/epoch - 9ms/step
# Epoch 847/3000
# 10/10 - 0s - loss: 6.4336e-04 - val_loss: 2.8035e-04 - 78ms/epoch - 8ms/step
# Epoch 848/3000
# 10/10 - 0s - loss: 6.2484e-04 - val_loss: 2.8002e-04 - 74ms/epoch - 7ms/step
# Epoch 849/3000
# 10/10 - 0s - loss: 6.3005e-04 - val_loss: 2.7962e-04 - 84ms/epoch - 8ms/step
# Epoch 850/3000
# 10/10 - 0s - loss: 6.3044e-04 - val_loss: 2.7928e-04 - 75ms/epoch - 8ms/step
# Epoch 851/3000
# 10/10 - 0s - loss: 6.2246e-04 - val_loss: 2.7896e-04 - 73ms/epoch - 7ms/step
# Epoch 852/3000
# 10/10 - 0s - loss: 6.8558e-04 - val_loss: 2.7862e-04 - 70ms/epoch - 7ms/step
# Epoch 853/3000
# 10/10 - 0s - loss: 6.2114e-04 - val_loss: 2.7831e-04 - 76ms/epoch - 8ms/step
# Epoch 854/3000
# 10/10 - 0s - loss: 6.2079e-04 - val_loss: 2.7796e-04 - 88ms/epoch - 9ms/step
# Epoch 855/3000
# 10/10 - 0s - loss: 6.2921e-04 - val_loss: 2.7758e-04 - 95ms/epoch - 9ms/step
# Epoch 856/3000
# 10/10 - 0s - loss: 6.4242e-04 - val_loss: 2.7724e-04 - 87ms/epoch - 9ms/step
# Epoch 857/3000
# 10/10 - 0s - loss: 6.1846e-04 - val_loss: 2.7693e-04 - 74ms/epoch - 7ms/step
# Epoch 858/3000
# 10/10 - 0s - loss: 6.1721e-04 - val_loss: 2.7661e-04 - 74ms/epoch - 7ms/step
# Epoch 859/3000
# 10/10 - 0s - loss: 6.1669e-04 - val_loss: 2.7627e-04 - 70ms/epoch - 7ms/step
# Epoch 860/3000
# ...
# 10/10 - 0s - loss: 3.7566e-05 - val_loss: 1.6821e-05 - 69ms/epoch - 7ms/step
# Epoch 2647/3000
# 10/10 - 0s - loss: 3.7459e-05 - val_loss: 1.6777e-05 - 73ms/epoch - 7ms/step
# Epoch 2648/3000
# 10/10 - 0s - loss: 3.7371e-05 - val_loss: 1.6734e-05 - 55ms/epoch - 6ms/step
# Epoch 2649/3000
# 10/10 - 0s - loss: 3.7277e-05 - val_loss: 1.6695e-05 - 71ms/epoch - 7ms/step
# Epoch 2650/3000
# 10/10 - 0s - loss: 3.7194e-05 - val_loss: 1.6656e-05 - 72ms/epoch - 7ms/step
# Epoch 2651/3000
# 10/10 - 0s - loss: 3.7106e-05 - val_loss: 1.6618e-05 - 71ms/epoch - 7ms/step
# Epoch 2652/3000
# 10/10 - 0s - loss: 3.7018e-05 - val_loss: 1.6580e-05 - 87ms/epoch - 9ms/step
# Epoch 2653/3000
# 10/10 - 0s - loss: 3.6931e-05 - val_loss: 1.6535e-05 - 54ms/epoch - 5ms/step
# Epoch 2654/3000
# 10/10 - 0s - loss: 3.6833e-05 - val_loss: 1.6495e-05 - 57ms/epoch - 6ms/step
# Epoch 2655/3000
# 10/10 - 0s - loss: 3.6744e-05 - val_loss: 1.6455e-05 - 57ms/epoch - 6ms/step
# Epoch 2656/3000
# 10/10 - 0s - loss: 3.6653e-05 - val_loss: 1.6409e-05 - 73ms/epoch - 7ms/step
# Epoch 2657/3000
# 10/10 - 0s - loss: 3.6549e-05 - val_loss: 1.6363e-05 - 58ms/epoch - 6ms/step
# Epoch 2658/3000
# 10/10 - 0s - loss: 4.0571e-05 - val_loss: 1.6320e-05 - 83ms/epoch - 8ms/step
# Epoch 2659/3000
# 10/10 - 0s - loss: 3.6351e-05 - val_loss: 1.6272e-05 - 77ms/epoch - 8ms/step
# Epoch 2660/3000
# 10/10 - 0s - loss: 3.8335e-05 - val_loss: 1.6230e-05 - 65ms/epoch - 6ms/step
# Epoch 2661/3000
# 10/10 - 0s - loss: 3.6155e-05 - val_loss: 1.6192e-05 - 75ms/epoch - 8ms/step
# Epoch 2662/3000
# 10/10 - 0s - loss: 3.6071e-05 - val_loss: 1.6153e-05 - 81ms/epoch - 8ms/step
# Epoch 2663/3000
# 10/10 - 0s - loss: 3.5987e-05 - val_loss: 1.6115e-05 - 80ms/epoch - 8ms/step
# Epoch 2664/3000
# 10/10 - 0s - loss: 5.1897e-05 - val_loss: 1.6071e-05 - 79ms/epoch - 8ms/step
# Epoch 2665/3000
# 10/10 - 0s - loss: 3.5799e-05 - val_loss: 1.6025e-05 - 72ms/epoch - 7ms/step
# Epoch 2666/3000
# 10/10 - 0s - loss: 0.0020 - val_loss: 1.5719e-05 - 60ms/epoch - 6ms/step
# Epoch 2667/3000
# 10/10 - 0s - loss: 3.4884e-05 - val_loss: 1.5583e-05 - 65ms/epoch - 7ms/step
# Epoch 2668/3000
# 10/10 - 0s - loss: 3.4696e-05 - val_loss: 1.5528e-05 - 60ms/epoch - 6ms/step
# Epoch 2669/3000
# 10/10 - 0s - loss: 3.5312e-05 - val_loss: 1.5501e-05 - 61ms/epoch - 6ms/step
# Epoch 2670/3000
# 10/10 - 0s - loss: 3.4574e-05 - val_loss: 1.5484e-05 - 61ms/epoch - 6ms/step
# Epoch 2671/3000
# 10/10 - 0s - loss: 3.4529e-05 - val_loss: 1.5471e-05 - 85ms/epoch - 9ms/step
# Epoch 2672/3000
# 10/10 - 0s - loss: 3.4486e-05 - val_loss: 1.5459e-05 - 69ms/epoch - 7ms/step
# Epoch 2673/3000
# 10/10 - 0s - loss: 3.8574e-05 - val_loss: 1.5449e-05 - 61ms/epoch - 6ms/step
# Epoch 2674/3000
# 10/10 - 0s - loss: 3.4463e-05 - val_loss: 1.5437e-05 - 57ms/epoch - 6ms/step
# Epoch 2675/3000
# 10/10 - 0s - loss: 3.4634e-05 - val_loss: 1.5426e-05 - 60ms/epoch - 6ms/step
# Epoch 2676/3000
# 10/10 - 0s - loss: 3.4388e-05 - val_loss: 1.5414e-05 - 57ms/epoch - 6ms/step
# Epoch 2677/3000
# 10/10 - 0s - loss: 3.4363e-05 - val_loss: 1.5403e-05 - 69ms/epoch - 7ms/step
# Epoch 2678/3000
# 10/10 - 0s - loss: 3.4337e-05 - val_loss: 1.5392e-05 - 58ms/epoch - 6ms/step
# Epoch 2679/3000
# 10/10 - 0s - loss: 3.4330e-05 - val_loss: 1.5381e-05 - 69ms/epoch - 7ms/step
# Epoch 2680/3000
# 10/10 - 0s - loss: 3.4321e-05 - val_loss: 1.5370e-05 - 61ms/epoch - 6ms/step
# Epoch 2681/3000
# 10/10 - 0s - loss: 3.4379e-05 - val_loss: 1.5359e-05 - 59ms/epoch - 6ms/step
# Epoch 2682/3000
# 10/10 - 0s - loss: 3.4237e-05 - val_loss: 1.5347e-05 - 71ms/epoch - 7ms/step
# Epoch 2683/3000
# 10/10 - 0s - loss: 3.4221e-05 - val_loss: 1.5336e-05 - 89ms/epoch - 9ms/step
# Epoch 2684/3000
# 10/10 - 0s - loss: 3.4183e-05 - val_loss: 1.5322e-05 - 86ms/epoch - 9ms/step
# Epoch 2685/3000
# 10/10 - 0s - loss: 3.4154e-05 - val_loss: 1.5309e-05 - 85ms/epoch - 8ms/step
# Epoch 2686/3000
# 10/10 - 0s - loss: 3.4125e-05 - val_loss: 1.5295e-05 - 99ms/epoch - 10ms/step
# Epoch 2687/3000
# 10/10 - 0s - loss: 3.4103e-05 - val_loss: 1.5282e-05 - 105ms/epoch - 11ms/step
# Epoch 2688/3000
# 10/10 - 0s - loss: 3.4089e-05 - val_loss: 1.5271e-05 - 106ms/epoch - 11ms/step
# Epoch 2689/3000
# 10/10 - 0s - loss: 5.6940e-05 - val_loss: 1.5261e-05 - 105ms/epoch - 11ms/step
# Epoch 2690/3000
# 10/10 - 0s - loss: 3.4020e-05 - val_loss: 1.5252e-05 - 108ms/epoch - 11ms/step
# Epoch 2691/3000
# 10/10 - 0s - loss: 3.3999e-05 - val_loss: 1.5240e-05 - 99ms/epoch - 10ms/step
# Epoch 2692/3000
# 10/10 - 0s - loss: 0.0026 - val_loss: 1.5433e-05 - 81ms/epoch - 8ms/step
# Epoch 2693/3000
# 10/10 - 0s - loss: 0.0067 - val_loss: 1.5434e-05 - 102ms/epoch - 10ms/step
# Epoch 2694/3000
# 10/10 - 0s - loss: 3.5540e-05 - val_loss: 1.5273e-05 - 110ms/epoch - 11ms/step
# Epoch 2695/3000
# 10/10 - 0s - loss: 3.3986e-05 - val_loss: 1.5214e-05 - 94ms/epoch - 9ms/step
# Epoch 2696/3000
# 10/10 - 0s - loss: 3.4187e-05 - val_loss: 1.5189e-05 - 106ms/epoch - 11ms/step
# Epoch 2697/3000
# 10/10 - 0s - loss: 3.4321e-05 - val_loss: 1.5178e-05 - 93ms/epoch - 9ms/step
# Epoch 2698/3000
# 10/10 - 0s - loss: 0.0011 - val_loss: 1.5246e-05 - 80ms/epoch - 8ms/step
# Epoch 2699/3000
# 10/10 - 0s - loss: 0.0121 - val_loss: 1.5401e-05 - 93ms/epoch - 9ms/step
# Epoch 2700/3000
# 10/10 - 0s - loss: 0.0103 - val_loss: 1.5451e-05 - 95ms/epoch - 10ms/step
# Epoch 2701/3000
# 10/10 - 0s - loss: 9.2059e-05 - val_loss: 1.5356e-05 - 90ms/epoch - 9ms/step
# Epoch 2702/3000
# 10/10 - 0s - loss: 3.4204e-05 - val_loss: 1.5321e-05 - 84ms/epoch - 8ms/step
# Epoch 2703/3000
# 10/10 - 0s - loss: 4.6696e-05 - val_loss: 1.5306e-05 - 83ms/epoch - 8ms/step
# Epoch 2704/3000
# 10/10 - 0s - loss: 4.1329e-05 - val_loss: 1.5298e-05 - 75ms/epoch - 8ms/step
# Epoch 2705/3000
# 10/10 - 0s - loss: 3.4107e-05 - val_loss: 1.5294e-05 - 79ms/epoch - 8ms/step
# Epoch 2706/3000
# 10/10 - 0s - loss: 3.4103e-05 - val_loss: 1.5290e-05 - 77ms/epoch - 8ms/step
# Epoch 2707/3000
# 10/10 - 0s - loss: 3.4091e-05 - val_loss: 1.5286e-05 - 85ms/epoch - 9ms/step
# Epoch 2708/3000
# 10/10 - 0s - loss: 0.0030 - val_loss: 1.5180e-05 - 93ms/epoch - 9ms/step
# Epoch 2709/3000
# 10/10 - 0s - loss: 3.3888e-05 - val_loss: 1.5141e-05 - 74ms/epoch - 7ms/step
# Epoch 2710/3000
# 10/10 - 0s - loss: 3.3979e-05 - val_loss: 1.5124e-05 - 108ms/epoch - 11ms/step
# Epoch 2711/3000
# 10/10 - 0s - loss: 3.3940e-05 - val_loss: 1.5117e-05 - 87ms/epoch - 9ms/step
# Epoch 2712/3000
# 10/10 - 0s - loss: 3.3836e-05 - val_loss: 1.5112e-05 - 94ms/epoch - 9ms/step
# Epoch 2713/3000
# 10/10 - 0s - loss: 3.3725e-05 - val_loss: 1.5109e-05 - 82ms/epoch - 8ms/step
# Epoch 2714/3000
# 10/10 - 0s - loss: 3.3690e-05 - val_loss: 1.5106e-05 - 78ms/epoch - 8ms/step
# Epoch 2715/3000
# 10/10 - 0s - loss: 3.3681e-05 - val_loss: 1.5103e-05 - 88ms/epoch - 9ms/step
# Epoch 2716/3000
# 10/10 - 0s - loss: 4.3159e-05 - val_loss: 1.5100e-05 - 83ms/epoch - 8ms/step
# Epoch 2717/3000
# 10/10 - 0s - loss: 3.3677e-05 - val_loss: 1.5098e-05 - 73ms/epoch - 7ms/step
# Epoch 2718/3000
# 10/10 - 0s - loss: 3.3667e-05 - val_loss: 1.5094e-05 - 91ms/epoch - 9ms/step
# Epoch 2719/3000
# 10/10 - 0s - loss: 3.3656e-05 - val_loss: 1.5091e-05 - 80ms/epoch - 8ms/step
# Epoch 2720/3000
# 10/10 - 0s - loss: 3.3648e-05 - val_loss: 1.5088e-05 - 80ms/epoch - 8ms/step
# Epoch 2721/3000
# 10/10 - 0s - loss: 3.3654e-05 - val_loss: 1.5085e-05 - 82ms/epoch - 8ms/step
# Epoch 2722/3000
# 10/10 - 0s - loss: 3.3813e-05 - val_loss: 1.5082e-05 - 89ms/epoch - 9ms/step
# Epoch 2723/3000
# 10/10 - 0s - loss: 3.3773e-05 - val_loss: 1.5080e-05 - 94ms/epoch - 9ms/step
# Epoch 2724/3000
# 10/10 - 0s - loss: 3.3663e-05 - val_loss: 1.5076e-05 - 77ms/epoch - 8ms/step
# Epoch 2725/3000
# 10/10 - 0s - loss: 3.3617e-05 - val_loss: 1.5073e-05 - 93ms/epoch - 9ms/step
# Epoch 2726/3000
# 10/10 - 0s - loss: 3.3621e-05 - val_loss: 1.5070e-05 - 80ms/epoch - 8ms/step
# Epoch 2727/3000
# 10/10 - 0s - loss: 5.0877e-05 - val_loss: 1.5067e-05 - 95ms/epoch - 10ms/step
# Epoch 2728/3000
# 10/10 - 0s - loss: 3.3852e-05 - val_loss: 1.5065e-05 - 88ms/epoch - 9ms/step
# Epoch 2729/3000
# 10/10 - 0s - loss: 3.5542e-05 - val_loss: 1.5062e-05 - 59ms/epoch - 6ms/step
# Epoch 2730/3000
# 10/10 - 0s - loss: 3.3583e-05 - val_loss: 1.5059e-05 - 53ms/epoch - 5ms/step
# Epoch 2731/3000
# 10/10 - 0s - loss: 3.3577e-05 - val_loss: 1.5057e-05 - 70ms/epoch - 7ms/step
# Epoch 2732/3000
# 10/10 - 0s - loss: 3.3571e-05 - val_loss: 1.5054e-05 - 61ms/epoch - 6ms/step
# Epoch 2733/3000
# 10/10 - 0s - loss: 3.3564e-05 - val_loss: 1.5050e-05 - 60ms/epoch - 6ms/step
# Epoch 2734/3000
# 10/10 - 0s - loss: 3.3556e-05 - val_loss: 1.5047e-05 - 57ms/epoch - 6ms/step
# Epoch 2735/3000
# 10/10 - 0s - loss: 3.5423e-05 - val_loss: 1.5044e-05 - 54ms/epoch - 5ms/step
# Epoch 2736/3000
# 10/10 - 0s - loss: 3.3543e-05 - val_loss: 1.5041e-05 - 72ms/epoch - 7ms/step
# Epoch 2737/3000
# 10/10 - 0s - loss: 3.3535e-05 - val_loss: 1.5037e-05 - 57ms/epoch - 6ms/step
# Epoch 2738/3000
# 10/10 - 0s - loss: 3.3526e-05 - val_loss: 1.5033e-05 - 55ms/epoch - 6ms/step
# Epoch 2739/3000
# 10/10 - 0s - loss: 3.3519e-05 - val_loss: 1.5030e-05 - 57ms/epoch - 6ms/step
# Epoch 2740/3000
# 10/10 - 0s - loss: 3.3511e-05 - val_loss: 1.5027e-05 - 70ms/epoch - 7ms/step
# Epoch 2741/3000
# 10/10 - 0s - loss: 3.4398e-05 - val_loss: 1.5024e-05 - 57ms/epoch - 6ms/step
# Epoch 2742/3000
# 10/10 - 0s - loss: 3.4550e-05 - val_loss: 1.5021e-05 - 69ms/epoch - 7ms/step
# Epoch 2743/3000
# 10/10 - 0s - loss: 5.9073e-05 - val_loss: 1.5018e-05 - 57ms/epoch - 6ms/step
# Epoch 2744/3000
# 10/10 - 0s - loss: 3.3502e-05 - val_loss: 1.5016e-05 - 58ms/epoch - 6ms/step
# Epoch 2745/3000
# 10/10 - 0s - loss: 3.3609e-05 - val_loss: 1.5013e-05 - 70ms/epoch - 7ms/step
# Epoch 2746/3000
# 10/10 - 0s - loss: 5.3887e-05 - val_loss: 1.5011e-05 - 72ms/epoch - 7ms/step
# Epoch 2747/3000
# 10/10 - 0s - loss: 3.3469e-05 - val_loss: 1.5008e-05 - 61ms/epoch - 6ms/step
# Epoch 2748/3000
# 10/10 - 0s - loss: 3.3463e-05 - val_loss: 1.5005e-05 - 68ms/epoch - 7ms/step
# Epoch 2749/3000
# 10/10 - 0s - loss: 3.3637e-05 - val_loss: 1.5002e-05 - 58ms/epoch - 6ms/step
# Epoch 2750/3000
# 10/10 - 0s - loss: 3.3655e-05 - val_loss: 1.4999e-05 - 58ms/epoch - 6ms/step
# Epoch 2751/3000
# 10/10 - 0s - loss: 3.3442e-05 - val_loss: 1.4995e-05 - 74ms/epoch - 7ms/step
# Epoch 2752/3000
# 10/10 - 0s - loss: 3.3481e-05 - val_loss: 1.4992e-05 - 64ms/epoch - 6ms/step
# Epoch 2753/3000
# 10/10 - 0s - loss: 3.3452e-05 - val_loss: 1.4989e-05 - 72ms/epoch - 7ms/step
# Epoch 2754/3000
# 10/10 - 0s - loss: 4.1629e-05 - val_loss: 1.4986e-05 - 58ms/epoch - 6ms/step
# Epoch 2755/3000
# 10/10 - 0s - loss: 3.3512e-05 - val_loss: 1.4983e-05 - 63ms/epoch - 6ms/step
# Epoch 2756/3000
# 10/10 - 0s - loss: 3.3407e-05 - val_loss: 1.4980e-05 - 55ms/epoch - 6ms/step
# Epoch 2757/3000
# 10/10 - 0s - loss: 3.3405e-05 - val_loss: 1.4976e-05 - 54ms/epoch - 5ms/step
# Epoch 2758/3000
# 10/10 - 0s - loss: 3.3392e-05 - val_loss: 1.4973e-05 - 69ms/epoch - 7ms/step
# Epoch 2759/3000
# 10/10 - 0s - loss: 3.4604e-05 - val_loss: 1.4970e-05 - 59ms/epoch - 6ms/step
# Epoch 2760/3000
# 10/10 - 0s - loss: 3.5383e-05 - val_loss: 1.4966e-05 - 56ms/epoch - 6ms/step
# Epoch 2761/3000
# 10/10 - 0s - loss: 3.4015e-05 - val_loss: 1.4963e-05 - 61ms/epoch - 6ms/step
# Epoch 2762/3000
# 10/10 - 0s - loss: 3.3361e-05 - val_loss: 1.4959e-05 - 74ms/epoch - 7ms/step
# Epoch 2763/3000
# 10/10 - 0s - loss: 3.3352e-05 - val_loss: 1.4955e-05 - 67ms/epoch - 7ms/step
# Epoch 2764/3000
# 10/10 - 0s - loss: 3.3572e-05 - val_loss: 1.4952e-05 - 93ms/epoch - 9ms/step
# Epoch 2765/3000
# 10/10 - 0s - loss: 3.3342e-05 - val_loss: 1.4947e-05 - 71ms/epoch - 7ms/step
# Epoch 2766/3000
# 10/10 - 0s - loss: 3.3325e-05 - val_loss: 1.4943e-05 - 83ms/epoch - 8ms/step
# Epoch 2767/3000
# 10/10 - 0s - loss: 3.3317e-05 - val_loss: 1.4939e-05 - 65ms/epoch - 6ms/step
# Epoch 2768/3000
# 10/10 - 0s - loss: 3.3309e-05 - val_loss: 1.4936e-05 - 68ms/epoch - 7ms/step
# Epoch 2769/3000
# 10/10 - 0s - loss: 3.3301e-05 - val_loss: 1.4932e-05 - 76ms/epoch - 8ms/step
# Epoch 2770/3000
# 10/10 - 0s - loss: 3.3409e-05 - val_loss: 1.4929e-05 - 63ms/epoch - 6ms/step
# Epoch 2771/3000
# 10/10 - 0s - loss: 4.6805e-05 - val_loss: 1.4925e-05 - 66ms/epoch - 7ms/step
# Epoch 2772/3000
# 10/10 - 0s - loss: 3.3279e-05 - val_loss: 1.4923e-05 - 67ms/epoch - 7ms/step
# Epoch 2773/3000
# 10/10 - 0s - loss: 3.3290e-05 - val_loss: 1.4919e-05 - 77ms/epoch - 8ms/step
# Epoch 2774/3000
# 10/10 - 0s - loss: 3.3298e-05 - val_loss: 1.4914e-05 - 69ms/epoch - 7ms/step
# Epoch 2775/3000
# 10/10 - 0s - loss: 3.3653e-05 - val_loss: 1.4910e-05 - 81ms/epoch - 8ms/step
# Epoch 2776/3000
# 10/10 - 0s - loss: 4.0775e-04 - val_loss: 1.4913e-05 - 68ms/epoch - 7ms/step
# Epoch 2777/3000
# 10/10 - 0s - loss: 3.3274e-05 - val_loss: 1.4930e-05 - 76ms/epoch - 8ms/step
# Epoch 2778/3000
# 10/10 - 0s - loss: 0.0019 - val_loss: 1.4841e-05 - 67ms/epoch - 7ms/step
# Epoch 2779/3000
# 10/10 - 0s - loss: 3.3330e-05 - val_loss: 1.4803e-05 - 91ms/epoch - 9ms/step
# Epoch 2780/3000
# 10/10 - 0s - loss: 3.3006e-05 - val_loss: 1.4786e-05 - 66ms/epoch - 7ms/step
# Epoch 2781/3000
# 10/10 - 0s - loss: 5.8793e-05 - val_loss: 1.4780e-05 - 77ms/epoch - 8ms/step
# Epoch 2782/3000
# 10/10 - 0s - loss: 3.2961e-05 - val_loss: 1.4775e-05 - 71ms/epoch - 7ms/step
# Epoch 2783/3000
# 10/10 - 0s - loss: 0.0018 - val_loss: 1.4798e-05 - 70ms/epoch - 7ms/step
# Epoch 2784/3000
# 10/10 - 0s - loss: 0.0017 - val_loss: 1.4933e-05 - 80ms/epoch - 8ms/step
# Epoch 2785/3000
# 10/10 - 0s - loss: 6.0245e-04 - val_loss: 1.4973e-05 - 80ms/epoch - 8ms/step
# Epoch 2786/3000
# 10/10 - 0s - loss: 5.4463e-05 - val_loss: 1.4971e-05 - 71ms/epoch - 7ms/step
# Epoch 2787/3000
# 10/10 - 0s - loss: 3.3380e-05 - val_loss: 1.4968e-05 - 63ms/epoch - 6ms/step
# Epoch 2788/3000
# 10/10 - 0s - loss: 4.9437e-04 - val_loss: 1.4936e-05 - 81ms/epoch - 8ms/step
# Epoch 2789/3000
# 10/10 - 0s - loss: 3.3291e-05 - val_loss: 1.4923e-05 - 72ms/epoch - 7ms/step
# Epoch 2790/3000
# 10/10 - 0s - loss: 3.3269e-05 - val_loss: 1.4916e-05 - 56ms/epoch - 6ms/step
# Epoch 2791/3000
# 10/10 - 0s - loss: 7.4095e-05 - val_loss: 1.4909e-05 - 68ms/epoch - 7ms/step
# Epoch 2792/3000
# 10/10 - 0s - loss: 3.3240e-05 - val_loss: 1.4904e-05 - 73ms/epoch - 7ms/step
# Epoch 2793/3000
# 10/10 - 0s - loss: 3.3229e-05 - val_loss: 1.4900e-05 - 57ms/epoch - 6ms/step
# Epoch 2794/3000
# 10/10 - 0s - loss: 3.3220e-05 - val_loss: 1.4896e-05 - 55ms/epoch - 6ms/step
# Epoch 2795/3000
# 10/10 - 0s - loss: 3.3210e-05 - val_loss: 1.4891e-05 - 72ms/epoch - 7ms/step
# Epoch 2796/3000
# 10/10 - 0s - loss: 3.3201e-05 - val_loss: 1.4887e-05 - 57ms/epoch - 6ms/step
# Epoch 2797/3000
# 10/10 - 0s - loss: 3.3191e-05 - val_loss: 1.4882e-05 - 57ms/epoch - 6ms/step
# Epoch 2798/3000
# 10/10 - 0s - loss: 3.3181e-05 - val_loss: 1.4879e-05 - 70ms/epoch - 7ms/step
# Epoch 2799/3000
# 10/10 - 0s - loss: 3.3174e-05 - val_loss: 1.4874e-05 - 74ms/epoch - 7ms/step
# Epoch 2800/3000
# 10/10 - 0s - loss: 3.3163e-05 - val_loss: 1.4871e-05 - 71ms/epoch - 7ms/step
# Epoch 2801/3000
# 10/10 - 0s - loss: 3.3155e-05 - val_loss: 1.4867e-05 - 70ms/epoch - 7ms/step
# Epoch 2802/3000
# 10/10 - 0s - loss: 3.3147e-05 - val_loss: 1.4863e-05 - 70ms/epoch - 7ms/step
# Epoch 2803/3000
# 10/10 - 0s - loss: 3.3138e-05 - val_loss: 1.4859e-05 - 72ms/epoch - 7ms/step
# Epoch 2804/3000
# 10/10 - 0s - loss: 3.3130e-05 - val_loss: 1.4855e-05 - 70ms/epoch - 7ms/step
# Epoch 2805/3000
# 10/10 - 0s - loss: 3.3121e-05 - val_loss: 1.4852e-05 - 55ms/epoch - 5ms/step
# Epoch 2806/3000
# 10/10 - 0s - loss: 3.3741e-05 - val_loss: 1.4848e-05 - 66ms/epoch - 7ms/step
# Epoch 2807/3000
# 10/10 - 0s - loss: 3.3106e-05 - val_loss: 1.4844e-05 - 55ms/epoch - 6ms/step
# Epoch 2808/3000
# 10/10 - 0s - loss: 3.3096e-05 - val_loss: 1.4841e-05 - 54ms/epoch - 5ms/step
# Epoch 2809/3000
# 10/10 - 0s - loss: 3.3088e-05 - val_loss: 1.4836e-05 - 74ms/epoch - 7ms/step
# Epoch 2810/3000
# 10/10 - 0s - loss: 3.3079e-05 - val_loss: 1.4832e-05 - 73ms/epoch - 7ms/step
# Epoch 2811/3000
# 10/10 - 0s - loss: 3.3070e-05 - val_loss: 1.4829e-05 - 71ms/epoch - 7ms/step
# Epoch 2812/3000
# 10/10 - 0s - loss: 3.3061e-05 - val_loss: 1.4824e-05 - 58ms/epoch - 6ms/step
# Epoch 2813/3000
# 10/10 - 0s - loss: 3.3052e-05 - val_loss: 1.4820e-05 - 58ms/epoch - 6ms/step
# Epoch 2814/3000
# 10/10 - 0s - loss: 3.3043e-05 - val_loss: 1.4816e-05 - 56ms/epoch - 6ms/step
# Epoch 2815/3000
# 10/10 - 0s - loss: 3.3034e-05 - val_loss: 1.4813e-05 - 69ms/epoch - 7ms/step
# Epoch 2816/3000
# 10/10 - 0s - loss: 3.3025e-05 - val_loss: 1.4808e-05 - 57ms/epoch - 6ms/step
# Epoch 2817/3000
# 10/10 - 0s - loss: 3.3015e-05 - val_loss: 1.4804e-05 - 73ms/epoch - 7ms/step
# Epoch 2817: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()

# %%
predictions = (model.predict(X_test) > 0.5)*1
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
# https://en.wikipedia.org/wiki/Precision_and_recall
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        95
#          1.0       1.00      1.00      1.00         3
#
#     accuracy                           1.00        98
#    macro avg       1.00      1.00      1.00        98
# weighted avg       1.00      1.00      1.00        98

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[95  0]
#  [ 0  3]]

# %%
cm_df = pd.DataFrame(confusion_matrix(y_test,predictions))
cm_df.columns = ['Predicted 0','Predicted 1']
cm_df = cm_df.rename(index={0: 'Actual 0',1:'Actual 1'})
cm_df
# Out:
#           Predicted 0  Predicted 1
# Actual 0           95            0
# Actual 1            0            3

# %%
from sklearn.metrics import f1_score

# %%
f1 = f1_score(y_test, predictions)
print (f1)
# Out:
# 1.0

# %%
CM = confusion_matrix(y_test,predictions)

TN = CM[0][0]
FN = CM[1][0]
TP = CM[1][1]
FP = CM[0][1]

# %%
# Sensitivity, hit rate, recall, or true positive rate
TPR = TP/(TP+FN)
# Specificity or true negative rate
TNR = TN/(TN+FP)
# Precision or positive predictive value
PPV = TP/(TP+FP)
# Negative predictive value
NPV = TN/(TN+FN)
# Fall out or false positive rate
FPR = FP/(FP+TN)
# False negative rate
FNR = FN/(TP+FN)
# False discovery rate
FDR = FP/(TP+FP)

# Overall accuracy
ACC = (TP+TN)/(TP+FP+FN+TN)

# %%
ACC
# Out:
# 1.0

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
ax1 = sns.distplot(df['Time'], ax=ax1, color='y')
ax2 = sns.distplot(df['Amount'], ax=ax2, color='r')
ax1.set_title('Distribution of Time', fontsize=13)
ax2.set_title('Distribution of Amount', fontsize=13)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-c4a29a2be327> in <cell line: 2>()
#       1 f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
# ----> 2 ax1 = sns.distplot(df['Time'], ax=ax1, color='y')
#       3 ax2 = sns.distplot(df['Amount'], ax=ax2, color='r')
#       4 ax1.set_title('Distribution of Time', fontsize=13)
#       5 ax2.set_title('Distribution of Amount', fontsize=13)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Time'

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()
df['scaled_amount'] = rs.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rs.fit_transform(df['Time'].values.reshape(-1,1))
df.drop(['Time', 'Amount'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-07656862badb> in <cell line: 4>()
#       2 rs = RobustScaler()
#       3 df['scaled_amount'] = rs.fit_transform(df['Amount'].values.reshape(-1,1))
# ----> 4 df['scaled_time'] = rs.fit_transform(df['Time'].values.reshape(-1,1))
#       5 df.drop(['Time', 'Amount'], axis=1, inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Time'

# %%
scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']
df.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(0, 'scaled_time', scaled_time)
df.head()

# %%
# Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset.
# It looks like unimportant. We'll drop that.

df=df_raw.drop(['Time'], axis=1)
